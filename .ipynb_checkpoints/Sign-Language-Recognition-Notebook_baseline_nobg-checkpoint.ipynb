# %% [markdown]
# ## TODO:
# + ~~Add transform to vid image? Yes, need to resize to 256~~
# + ~~Standardize number of frame. OR find a way to group dataset by similar frames.~~
# + Test around with frame number and evaluate training time.
# + Replace LSTM+Attention with Transformer
# + Image Segmentation? Pose estimation? Facial recognition
# + Data visualisation of the number of video frame
# + Start on the report
# + GUI?
#
#
#
# Step to set up working directory:
# 1. Git clone folder:
# ```bash
# git clone https://github.com/victorpham1997/Sign-Language-Recognition-using-Deep-Learning.git
# ```
# 2. Download train dataset:<br>
#     Download from here: http://chalearnlap.cvc.uab.es/dataset/40/data/66/files/
#
# 3. Extract train dataset: <br>
#     Train dataset decompress password: MdG3z6Eh1t
#
# 4. Download validation dataset <br>
#     Download from here: http://chalearnlap.cvc.uab.es/dataset/40/data/65/files/
#
# 5. Extract val dataset: <br>
#     Train dataset decompress password: bhRY5B9zS2
# 6. Rename and move the train, val folder to follow: <br>
# Sign-Language-Recognition-using-Deep-Learning/dataset/train/\*all train image here*<br>
# Sign-Language-Recognition-using-Deep-Learning/dataset/val/\*all val image here*

# %%
# !pip install torch-summary
 
import numpy as np
import cv2
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from glob import glob
from tqdm import tqdm

import torchvision
from torchvision import models
from torchsummary import summary
import time

import os
import pandas as pd
import math
# from AUTSLDataset import AUTSLDataset
# Out:
# Requirement already satisfied: torch-summary in /opt/conda/lib/python3.6/site-packages (1.4.5)

# %%
l = pd.read_csv("./dataset/nobg/train_labels.csv",names = ["file_name", "label"])
# l["signer"] = l.apply(lambda r: int(r.file_name.split("_")[0][6:]), axis =1)
# t = l[l.label <30]
# # np.unique(t).shape
# t["sdf"] = t.file_name + "_color.mp4"
# t.sdf.to_list()
min(l.label)
# Out:
# 0

# %% [markdown]
# ## Dataset Class

# %% [markdown]
# #### Dataset class with half frame rate and 0 padding

# %%
class AUTSLDataset(Dataset):
    '''
    Dataset for the AUTSL data
    '''
    
    def __init__(self, data_type, max_frame_no, num_class=226 ,frame_interval = 1, file_percentage = 1.0, data_path ="./dataset/nobg/" ):
        self.data_type = data_type
        self.frame_interval = frame_interval
        self.data_path = data_path+self.data_type+"/"
        self.label_path = data_path + self.data_type+"_labels.csv"

        df = pd.read_csv(self.label_path,names = ["file_name", "label"])
        self.num_class = num_class  
        self.df = df[df.label < self.num_class]
        self.df["file"] = self.df.file_name + "_color.mp4"
        
        self.file_ls = self.df.file.to_list()
        self.data_length = len(self.file_ls)
    
        self.max_frame_no = max_frame_no
        self.device = "cuda"

#         self.max = self.get_max()
        
    def Describe(self):
        msg = "AUTSL Dataset\n"
        print(msg)
    
#     def CreateLabel(self):
#         label_df = pd.read_csv(self.label_path[self.data_type],names = ["file_name", "label"])
#         label_df["signer"] = label_df.apply(lambda r: int(r.file_name.split("_")[0][6:]), axis =1)
#         return label_df   
        
    def GetLabel(self, file):
        return self.df[self.df.file ==file]["label"].values[0]
    
    def GetVideoArray(self, file_name):

        cap = cv2.VideoCapture(self.data_path + file_name)   # capturing the video from the given path
        video_arr = []
        while(cap.isOpened()):
            frameId = cap.get(1) #current frame number
            ret, frame = cap.read()
            if (ret != True):
                break
            if (frameId % self.frame_interval == 0):
                # Converting to tensor
                frame =  torchvision.transforms.functional.to_tensor(frame).float().to(self.device)
                frame = frame.unsqueeze(0)
#                 frame =  F.interpolate(frame, (256,256), mode='bilinear')
                frame = frame.squeeze(0)
                video_arr.append(frame)
        cap.release()

    
        if len(video_arr)<self.max_frame_no:
            empty_frame = torch.zeros((3,256,256)).to(self.device)
            padding  = [empty_frame]*(self.max_frame_no-len(video_arr))
            video_arr+=padding
            
        
#         print(video_arr)
#         assert len(video_arr) >0, f"Video {file_name} contain empty frames"
        if len(video_arr) <=0:
            return torch.empty(0)

        return torch.stack(video_arr) 
        
    def __len__(self):
        return self.data_length
    
    def __getitem__(self, index):
        '''
        Return 4D array consists of all the frame of the video image AND the label
        '''
        file_name = os.path.basename(self.file_ls[index])
        # print(file_name)
        video_arr = self.GetVideoArray(file_name)
        
        label = self.GetLabel(file_name)
        return video_arr, label
        
    def get_max(self):
        max_length = 0
        for i in tqdm(range(len(self))):
            video, label = self[i]
            if video.shape[0]>max_length:
                max_length = video.shape[0]
        return max_length

# %%
batch_size = 1
num_classes = 30

train_autsl = AUTSLDataset("train", -1, num_classes, frame_interval=2, file_percentage=0.3)
val_autsl = AUTSLDataset("val", -1, num_classes, frame_interval=2, file_percentage=0.3)
trainloader = DataLoader(train_autsl, batch_size=batch_size, shuffle=True)
valloader = DataLoader(val_autsl, batch_size=batch_size, shuffle=True)

print(f"Length of train dataset: {len(train_autsl)}")
print(f"Length of val dataset: {len(val_autsl)}")
start = time.process_time()
video, label = train_autsl[4]
print(f"Time taken to load 1 datapoint = {time.process_time() - start}")
print(f"Sample training data:\ninput shape: {video.shape}\noutput: {label}")
plt.imshow(video[0].cpu().permute(1,2,0))
# Out:
# Length of train dataset: 3696
# Length of val dataset: 578
# Time taken to load 1 datapoint = 0.032974334999991584
# Sample training data:
# input shape: torch.Size([12, 3, 256, 256])
# output: 1
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
video.shape
# Out:
# torch.Size([12, 3, 256, 256])

# %% [markdown]
# ## Baseline model
#
# In the next section, we will try to recreate the baseline model from the "AUTSL: A Large Scale Multi-modal Turkish Sign Language Dataset and Baseline Methods" paper.<br>
# The following section from the model may be useful when recreating the baseline model:

# %% [markdown]
# ### 4.2 Baseline Models
# We construct five deep neural networks for the empirical evaluations. In all the models, we use
# CNNs to extract spatial features from each frame. In our experiments, we investigate the contributions
# of using a feature pooling module and temporal attention model as we described in Section 4.1. We
# also compare the performances using simple unidirectional LSTM and bidirectional LSTMs. All our
# networks, as illustrated in Fig. 5, are separately trained end-to-end.<br>
# #### CNN + LSTM Model:
# In our models, we conduct our experiments using only RGB and
# RGB-D modalities, with minor modifications. In order to use the depth data, which is represented as
# a single channel gray-scale image for each frame, with the pretrained VGG model, we repeat the same
# depth data into three color channels as in [56]. Then, RGB and depth modalities are given as inputs to
# the two parallel VGG models with exact same architectures and applying similar training regime as we
# described in the previous section. CNN networks extract features and generate two feature matrices,
# i.e. one for the RGB data and one for the depth data. Then, we apply global average pooling and
# reduce the feature map dimensions to a vector of size 512 for each modality, separately. In the RGB
# only model, we feed 512-dimensional feature vectors into the LSTM model. On the other hand, in the
# RGB-D network, we concatenate two feature vectors with late fusion and obtain a 1024-dimensional
# feature vector. LSTM model generates scores using the the last hidden state vector, i.e. h t , after
# passing it to the Fully Connected (FC) layer. Since we have 226 signs, FC layer is set to have 226
# neural units. The scores of the FC layers are fed to a softmax classifier. We refer to this model as CNN + LSTM from now on.<br>
# #### CNN + FPM + LSTM Model:
# In the second model, our motivation is to represent the
# generated features in multiple-scales, so that we can get more contextual clues for classification of
# individual signs. We add an FPM module after the last CNN layer for that purpose. After that, we
# apply global average pooling to the extracted features. In the RGB-D model, we again concatenate the
# two feature vectors with a late fusion. Then, we send extracted features to LSTM. All the architectures,
# i.e. CNN and LSTM, are the same with the previous model, except for the addition of the FPM module
# in between these models. As we stated before, all the parameters of this network is trained end-to-end
# from scratch. We refer to this model as CNN + FPM + LSTM.<br>
# #### CNN + LSTM + Attention Model:
# Attention mechanisms have recently shown considerable
# improvements to many computer vision tasks. Therefore, we also want to investigate the contribution
# of attention to the classification performance with our dataset. The architecture is designed as follows:
# First, we extract the features with CNN and then apply global average pooling as in CNN + LSTM
# model. The only difference of this method from CNN + LSTM model is that we incorporate a temporal
# attention mechanism to the features that are passed to the LSTM model. We produce a context vector,
# c, using all the hidden states as we explained in detail in Section 4.1. We then send this context vector,
# instead of the last hidden state, to the FC layer. Finally, we use a softmax classifier. This model is
# referred to as CNN + LSTM + Attention.<br>
# #### CNN + FPM + LSTM + Attention Model:
# In this model, we observe the contribution of
# using both FPM and a temporal attention mechanism. At first, we extract features with CNN and pass
# the resultant feature maps to FPM. Then, we use the attention-based LSTM. Here again, we send the
# context vector to the FC layer and use softmax classifier. This model is referred to as CNN + FPM +
# LSTM+ Attention.<br>
# #### CNN + FPM + BLSTM + Attention Model:
# Finally, we want to investigate the classi-
# fication performance using bidirectional LSTMs with AUTSL dataset. We configured the components
# of the model as in the CNN + FPM + LSTM + Attention model, but we use attention based BLSTM
# instead of LSTM this time.

# %% [markdown]
# ![image](data:image/jpeg;base64,...)

# %%
class cnn(nn.Module):
    def __init__(self):
        super(cnn, self).__init__()
        self.pretrained_vgg = models.vgg16(pretrained=True)
        self.pretrained_vgg = nn.Sequential(*list(self.pretrained_vgg.features.children())[:-5])

        # Freeze parameter
        for param in self.pretrained_vgg.parameters():
            param.requires_grad = False

        # Manually add in the layers that are going to be finetuned
        self.pretrained_vgg.add_module("conv5_2", nn.Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.pretrained_vgg.add_module("relu5_2", nn.ReLU(inplace=True))
        self.pretrained_vgg.add_module("conv5_3", nn.Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
        self.pretrained_vgg.add_module("relu5_3", nn.ReLU(inplace=True))
        
    def forward(self, x):
        '''
        Input shape = (batchsize, seq, 3, h, w)
        '''
        output = self.pretrained_vgg(x)
        return output
        
        
class fpm(nn.Module):
    def __init__(self):
        super(fpm, self).__init__()
        self.pool1_0 = nn.MaxPool2d(kernel_size=2, stride=1, padding=1,dilation=2)
        self.conv1_1 = nn.Conv2d(in_channels=512,out_channels=128,kernel_size=1)
        self.conv2_0 = nn.Conv2d(in_channels=512,out_channels=128,kernel_size=3,padding=1)
        self.conv3_0 = nn.Conv2d(in_channels=512,out_channels=128,kernel_size=3,padding=2,dilation=2)
        self.conv4_0 = nn.Conv2d(in_channels=512,out_channels=128,kernel_size=3,padding=4,dilation=4)
        
    def forward(self, x):
        '''
        Input shape = (batchsize, seq, 512, 16, 16)
        '''
        x_1 = self.pool1_0(x)
        x_1 = F.relu(self.conv1_1(x_1))
        x_2 = F.relu(self.conv2_0(x))
        x_3 = F.relu(self.conv3_0(x))
        x_4 = F.relu(self.conv4_0(x))
        
        out = torch.cat([x_1,x_2,x_3,x_4], dim=1)
        
        return out

    
class lstm(nn.Module):
    def __init__(self, input_size, hidden_size, bidirectional = True):
        super(lstm, self).__init__()
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.bidirectional = bidirectional
        
        self.lstm = nn.LSTM(self.input_size, self.hidden_size, batch_first = True , bidirectional=self.bidirectional)
    
    def forward(self, inputs, hidden):
#         print(hidden[0].shape,hidden[1].shape)
        output, hidden_state = self.lstm(inputs, hidden)
#         print(output.shape, hidden[0].shape,hidden[1].shape)
        return output, hidden_state 
    
    def init_hidden(self, batch_size):
        return (torch.zeros(1 + int(self.bidirectional), batch_size, self.hidden_size), torch.zeros(1 + int(self.bidirectional), batch_size, self.hidden_size))
    
    
class attention(nn.Module):
    def __init__(self):
        super(attention, self).__init__()
        self.dropout_p = 0.25
        self.dropout1 = nn.Dropout(self.dropout_p)
        self.dropout2 = nn.Dropout(self.dropout_p)
        self.linear1 = nn.Linear(1024, 1024)
        self.linear2 = nn.Linear(1024, 1, bias=False)
        
        
    def forward(self, x):
        hidden = x
#         print(inputs.shape, hidden.shape)
        x = torch.tanh(self.linear1(x))
        x = self.dropout1(x)
        x = self.linear2(x)
        x = self.dropout2(x)
        x = F.softmax(x, dim=len(x.shape)-1)
        
#         print(x.shape,hidden.shape)
#         print((x*hidden).shape)
        
        c = torch.sum(x*hidden, dim=1)
    
        return c
    

class BaselineModel(nn.Module):
    def __init__(self, num_classes):
        super(BaselineModel, self).__init__()
        self.bidirectional = True
        self.lstm_hiddensize = 512
        self.dropout_p = 0.25
        
        self.cnn = cnn()
        self.fpm = fpm()
        self.lstm = lstm(512, self.lstm_hiddensize, self.bidirectional)
        self.attn = attention()
        self.dropout1 = nn.Dropout(self.dropout_p)
        self.fc = nn.Linear(1024,num_classes)
        
        
    def forward(self,x):
        embedding_output = []
        for i in range(x.size(1)):
            x_i = self.cnn(x[:,i,:,:,:])
            x_i = self.fpm(x_i)
            x_i = x_i.mean([-2, -1]) #Global Average Pooling
            
            embedding_output.append(x_i)
        
        embedding_output = torch.stack(embedding_output, dim=1)
#         print(embedding_output.shape[0])
        
        h_0, h_1 = self.lstm.init_hidden(embedding_output.shape[0])
        h_0 = h_0.to("cuda")
        h_1 = h_1.to("cuda")
        
        output, (final_hidden_state, final_cell_state) = self.lstm(embedding_output, (h_0,h_1)) # final_hidden_state.size() = (1, batch_size, hidden_size) 
        c = self.attn(output)
#         print(c.shape)
        output = self.dropout1(self.fc(c))
        output = F.log_softmax(output, dim=len(output.shape)-1)
        
        return output

# %%
model = BaselineModel(num_classes)
# x = torch.rand((5, 4, 3, 256, 256))
summary(model, (4, 3, 256, 256), device="cuda")

# Define Parameter here:
model_type = "baseline"
model_path = "./model/"
batch_size = 1
n_epochs = 10
lr = 1e-5
steps = 0 
print_every = 50
validate_every = 1500
device = "cuda"

train_loss_ls = []
val_loss_ls = []


time_stamp = str(time.time()).split(".")[0]
current_model_path = model_path + f"{model_type}-{time_stamp}-{n_epochs}e-{batch_size}b/"
os.mkdir(current_model_path)


criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=lr )
model.to(device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─cnn: 1-1                               [-1, 512, 16, 16]         --
# |    └─Sequential: 2-1                   [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-1                  [-1, 64, 256, 256]        (1,792)
# |    |    └─ReLU: 3-2                    [-1, 64, 256, 256]        --
# |    |    └─Conv2d: 3-3                  [-1, 64, 256, 256]        (36,928)
# |    |    └─ReLU: 3-4                    [-1, 64, 256, 256]        --
# |    |    └─MaxPool2d: 3-5               [-1, 64, 128, 128]        --
# |    |    └─Conv2d: 3-6                  [-1, 128, 128, 128]       (73,856)
# |    |    └─ReLU: 3-7                    [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-8                  [-1, 128, 128, 128]       (147,584)
# |    |    └─ReLU: 3-9                    [-1, 128, 128, 128]       --
# |    |    └─MaxPool2d: 3-10              [-1, 128, 64, 64]         --
# |    |    └─Conv2d: 3-11                 [-1, 256, 64, 64]         (295,168)
# |    |    └─ReLU: 3-12                   [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-13                 [-1, 256, 64, 64]         (590,080)
# |    |    └─ReLU: 3-14                   [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-15                 [-1, 256, 64, 64]         (590,080)
# |    |    └─ReLU: 3-16                   [-1, 256, 64, 64]         --
# |    |    └─MaxPool2d: 3-17              [-1, 256, 32, 32]         --
# |    |    └─Conv2d: 3-18                 [-1, 512, 32, 32]         (1,180,160)
# |    |    └─ReLU: 3-19                   [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-20                 [-1, 512, 32, 32]         (2,359,808)
# |    |    └─ReLU: 3-21                   [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-22                 [-1, 512, 32, 32]         (2,359,808)
# |    |    └─ReLU: 3-23                   [-1, 512, 32, 32]         --
# |    |    └─MaxPool2d: 3-24              [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-25                 [-1, 512, 16, 16]         (2,359,808)
# |    |    └─ReLU: 3-26                   [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-27                 [-1, 512, 16, 16]         2,359,808
# |    |    └─ReLU: 3-28                   [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-29                 [-1, 512, 16, 16]         2,359,808
# |    |    └─ReLU: 3-30                   [-1, 512, 16, 16]         --
# ├─fpm: 1-2                               [-1, 512, 16, 16]         --
# |    └─MaxPool2d: 2-2                    [-1, 512, 16, 16]         --
# |    └─Conv2d: 2-3                       [-1, 128, 16, 16]         65,664
# |    └─Conv2d: 2-4                       [-1, 128, 16, 16]         589,952
# |    └─Conv2d: 2-5                       [-1, 128, 16, 16]         589,952
# |    └─Conv2d: 2-6                       [-1, 128, 16, 16]         589,952
# ├─cnn: 1-3                               [-1, 512, 16, 16]         (recursive)
# |    └─Sequential: 2-7                   [-1, 512, 16, 16]         (recursive)
# |    |    └─Conv2d: 3-31                 [-1, 64, 256, 256]        (recursive)
# |    |    └─ReLU: 3-32                   [-1, 64, 256, 256]        --
# |    |    └─Conv2d: 3-33                 [-1, 64, 256, 256]        (recursive)
# |    |    └─ReLU: 3-34                   [-1, 64, 256, 256]        --
# |    |    └─MaxPool2d: 3-35              [-1, 64, 128, 128]        --
# |    |    └─Conv2d: 3-36                 [-1, 128, 128, 128]       (recursive)
# |    |    └─ReLU: 3-37                   [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-38                 [-1, 128, 128, 128]       (recursive)
# |    |    └─ReLU: 3-39                   [-1, 128, 128, 128]       --
# |    |    └─MaxPool2d: 3-40              [-1, 128, 64, 64]         --
# |    |    └─Conv2d: 3-41                 [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-42                   [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-43                 [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-44                   [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-45                 [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-46                   [-1, 256, 64, 64]         --
# |    |    └─MaxPool2d: 3-47              [-1, 256, 32, 32]         --
# |    |    └─Conv2d: 3-48                 [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-49                   [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-50                 [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-51                   [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-52                 [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-53                   [-1, 512, 32, 32]         --
# |    |    └─MaxPool2d: 3-54              [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-55                 [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-56                   [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-57                 [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-58                   [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-59                 [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-60                   [-1, 512, 16, 16]         --
# ├─fpm: 1-4                               [-1, 512, 16, 16]         (recursive)
# |    └─MaxPool2d: 2-8                    [-1, 512, 16, 16]         --
# |    └─Conv2d: 2-9                       [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-10                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-11                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-12                      [-1, 128, 16, 16]         (recursive)
# ├─cnn: 1-5                               [-1, 512, 16, 16]         (recursive)
# |    └─Sequential: 2-13                  [-1, 512, 16, 16]         (recursive)
# |    |    └─Conv2d: 3-61                 [-1, 64, 256, 256]        (recursive)
# |    |    └─ReLU: 3-62                   [-1, 64, 256, 256]        --
# |    |    └─Conv2d: 3-63                 [-1, 64, 256, 256]        (recursive)
# |    |    └─ReLU: 3-64                   [-1, 64, 256, 256]        --
# |    |    └─MaxPool2d: 3-65              [-1, 64, 128, 128]        --
# |    |    └─Conv2d: 3-66                 [-1, 128, 128, 128]       (recursive)
# |    |    └─ReLU: 3-67                   [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-68                 [-1, 128, 128, 128]       (recursive)
# |    |    └─ReLU: 3-69                   [-1, 128, 128, 128]       --
# |    |    └─MaxPool2d: 3-70              [-1, 128, 64, 64]         --
# |    |    └─Conv2d: 3-71                 [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-72                   [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-73                 [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-74                   [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-75                 [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-76                   [-1, 256, 64, 64]         --
# |    |    └─MaxPool2d: 3-77              [-1, 256, 32, 32]         --
# |    |    └─Conv2d: 3-78                 [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-79                   [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-80                 [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-81                   [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-82                 [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-83                   [-1, 512, 32, 32]         --
# |    |    └─MaxPool2d: 3-84              [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-85                 [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-86                   [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-87                 [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-88                   [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-89                 [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-90                   [-1, 512, 16, 16]         --
# ├─fpm: 1-6                               [-1, 512, 16, 16]         (recursive)
# |    └─MaxPool2d: 2-14                   [-1, 512, 16, 16]         --
# |    └─Conv2d: 2-15                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-16                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-17                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-18                      [-1, 128, 16, 16]         (recursive)
# ├─cnn: 1-7                               [-1, 512, 16, 16]         (recursive)
# |    └─Sequential: 2-19                  [-1, 512, 16, 16]         (recursive)
# |    |    └─Conv2d: 3-91                 [-1, 64, 256, 256]        (recursive)
# |    |    └─ReLU: 3-92                   [-1, 64, 256, 256]        --
# |    |    └─Conv2d: 3-93                 [-1, 64, 256, 256]        (recursive)
# |    |    └─ReLU: 3-94                   [-1, 64, 256, 256]        --
# |    |    └─MaxPool2d: 3-95              [-1, 64, 128, 128]        --
# |    |    └─Conv2d: 3-96                 [-1, 128, 128, 128]       (recursive)
# |    |    └─ReLU: 3-97                   [-1, 128, 128, 128]       --
# |    |    └─Conv2d: 3-98                 [-1, 128, 128, 128]       (recursive)
# |    |    └─ReLU: 3-99                   [-1, 128, 128, 128]       --
# |    |    └─MaxPool2d: 3-100             [-1, 128, 64, 64]         --
# |    |    └─Conv2d: 3-101                [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-102                  [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-103                [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-104                  [-1, 256, 64, 64]         --
# |    |    └─Conv2d: 3-105                [-1, 256, 64, 64]         (recursive)
# |    |    └─ReLU: 3-106                  [-1, 256, 64, 64]         --
# |    |    └─MaxPool2d: 3-107             [-1, 256, 32, 32]         --
# |    |    └─Conv2d: 3-108                [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-109                  [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-110                [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-111                  [-1, 512, 32, 32]         --
# |    |    └─Conv2d: 3-112                [-1, 512, 32, 32]         (recursive)
# |    |    └─ReLU: 3-113                  [-1, 512, 32, 32]         --
# |    |    └─MaxPool2d: 3-114             [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-115                [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-116                  [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-117                [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-118                  [-1, 512, 16, 16]         --
# |    |    └─Conv2d: 3-119                [-1, 512, 16, 16]         (recursive)
# |    |    └─ReLU: 3-120                  [-1, 512, 16, 16]         --
# ├─fpm: 1-8                               [-1, 512, 16, 16]         (recursive)
# |    └─MaxPool2d: 2-20                   [-1, 512, 16, 16]         --
# |    └─Conv2d: 2-21                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-22                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-23                      [-1, 128, 16, 16]         (recursive)
# |    └─Conv2d: 2-24                      [-1, 128, 16, 16]         (recursive)
# ├─lstm: 1-9                              [-1, 4, 1024]             --
# |    └─LSTM: 2-25                        [-1, 4, 1024]             4,202,496
# ├─attention: 1-10                        [-1, 1024]                --
# |    └─Linear: 2-26                      [-1, 4, 1024]             1,049,600
# |    └─Dropout: 2-27                     [-1, 4, 1024]             --
# |    └─Linear: 2-28                      [-1, 4, 1]                1,024
# |    └─Dropout: 2-29                     [-1, 4, 1]                --
# ├─Linear: 1-11                           [-1, 30]                  30,750
# ├─Dropout: 1-12                          [-1, 30]                  --
# ==========================================================================================
# Total params: 21,834,078
# Trainable params: 11,839,006
# Non-trainable params: 9,995,072
# Total mult-adds (G): 82.19
# ==========================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 136.06
# Params size (MB): 83.29
# Estimated Total Size (MB): 222.35
# ==========================================================================================
# BaselineModel(
#   (cnn): cnn(
#     (pretrained_vgg): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (conv5_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu5_2): ReLU(inplace=True)
#       (conv5_3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu5_3): ReLU(inplace=True)
#     )
#   )
#   (fpm): fpm(
#     (pool1_0): MaxPool2d(kernel_size=2, stride=1, padding=1, dilation=2, ceil_mode=False)
#     (conv1_1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#     (conv2_0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3_0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (conv4_0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#   )
#   (lstm): lstm(
#     (lstm): LSTM(512, 512, batch_first=True, bidirectional=True)
#   )
#   (attn): attention(
#     (dropout1): Dropout(p=0.25, inplace=False)
#     (dropout2): Dropout(p=0.25, inplace=False)
#     (linear1): Linear(in_features=1024, out_features=1024, bias=True)
#     (linear2): Linear(in_features=1024, out_features=1, bias=False)
#   )
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (fc): Linear(in_features=1024, out_features=30, bias=True)
# )

# %%
from torchsummary import summary
import torch
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from tqdm import tqdm
from datetime import datetime
from matplotlib import pyplot as plt


def validation(model, testloader, criterion, device):
    test_loss = 0
    accuracy = 0
#     confusion_matrix = torch.zeros(num_classes, num_classes)
    with tqdm(testloader, position=0, leave=False) as progress_bar:          
        for images, labels in progress_bar:
    #     for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)

            output = model(images)
            test_loss += criterion(output, labels).item()

            ps = torch.exp(output)
            predictions = ps.max(dim=1)[1]
            equality = (labels.data == predictions)
            accuracy += equality.type(torch.FloatTensor).mean()

    #         for label, prediction in zip(labels.view(-1), predictions.view(-1)):
    #             confusion_matrix[label.long(), prediction.long()] += 1

    return test_loss, accuracy


def test(model, testloader, device='cuda'):  
    model.to(device)
    accuracy = 0

    with torch.no_grad():
        model.eval()
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
                    
            output = model(images)
            
            ps = torch.exp(output)
            predictions = ps.max(dim=1)[1]
            equality = (labels.data == predictions)
            accuracy += equality.type(torch.FloatTensor).mean()

            for t, p in zip(labels.view(-1), predictions.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        
        print('Testing accuracy: {:.3f}'.format(accuracy/len(testloader)))
        print(f'Testing recall: {recall:.3f}')
        print(f'Testing precision: {precision:.3f}')
        print(f'Testing f1: {f1:.3f}')

    return accuracy, confusion_matrix


def train(model, model_name, batch_size, n_epochs, lr, train_loader, val_loader, saved_model_path, device = "cuda"):
#     input_sample, _ =  next(iter(train_loader))
#     print(summary(model, tuple(input_sample.shape[1:]), device=device))

    start_time = datetime.now()


    criterion = nn.NLLLoss()
    optimizer = optim.Adam(model.parameters(), lr= lr)
#     if use_lr_scheduler:
#         scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.01)


    train_loss_ls = []
    val_loss_ls = []
    val_acc_ls = []
    train_acc_ls = []
    
    best_accuracy = 0
    best_recall = 0
    best_accuracy_weights = None
    best_recall_weights = None
    
    steps = 0
    
    train_acc = 0
    
    
    running_loss = 0.0
    running_loss2 = 0.0
    print("Training started")
    for e in range(n_epochs):  # loop over the dataset multiple times

        # Training
        model.train()
        for idx, (images, labels) in enumerate(train_loader) :
#             print(idx)
            if images.nelement() == 0:
                continue
            steps += 1
#                 images, labels = images.to(device), labels.to(device)
            labels = labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            output = model(images)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            
            ps = torch.exp(output)
            predictions = ps.max(dim=1)[1]
            equality = (labels.data == predictions)
            train_acc += equality.type(torch.FloatTensor).mean()

            # print statistics
            running_loss += loss.item()
            running_loss2 += loss.item()
            

            if steps % validate_every == 0:

                # Eval mode for predictions
                model.eval()

                # Turn off gradients for validation
                with torch.no_grad():
                    test_loss, test_accuracy = validation(model, val_loader, criterion, device)

                running_loss /= validate_every
                train_acc /= validate_every
                print(f"Epoch: {e+1}/{ n_epochs} - Training Loss: {running_loss} - Validation Loss: {test_loss/len(val_loader)} - Train Accuracy:  {train_acc} - Validation Accuracy:  {test_accuracy/len(val_loader)}")

                train_loss_ls.append(running_loss) #/print_every
                val_loss_ls.append(test_loss/len(val_loader))
                val_acc_ls.append(test_accuracy/len(val_loader))
                train_acc_ls.append(train_acc)
                running_loss = 0        
                train_acc = 0        
#                 validate_every = 0
                # Make sure training is back on
                model.train()

            elif  steps % print_every == 0:
                print("Epoch: {}/{} - ".format(e+1, n_epochs), f"- Step: {idx}/{len(train_loader)}" , "Training Loss: {:.3f} - ".format(running_loss2/print_every))
                running_loss2 = 0
                    
        filepath = saved_model_path + f"{model_name}-{start_time}-b{batch_size}-e{e}.pt"
        torch.save(model, filepath)

    print("Finished training")
    
    fig, axs = plt.subplots(2,figsize=(10,15))
    
    axs[0].plot(train_loss_ls, label = "train_loss")
    axs[0].plot(val_loss_ls, label = "val_loss")
    axs[0].legend()
    
    axs[1].plot(train_acc_ls,label = "train_acc")
    axs[1].plot(val_acc_ls,label = "val_acc")
    axs[1].legend()

    fig.savefig(saved_model_path+'history.png')
    fig.show()
    return model.state_dict(), (train_loss_ls, val_loss_ls,val_acc_ls,train_acc_ls)

# %%
last_weights, history = train(model, "baseline_nobg", batch_size, 8, 1e-5, trainloader, valloader, saved_model_path=current_model_path)
last_weights, history2 = train(model, "baseline_nobg", batch_size, 5, 5e-5, trainloader, valloader, saved_model_path=current_model_path)
last_weights, history3 = train(model, "baseline_nobg", batch_size, 7, 1e-6, trainloader, valloader, saved_model_path=current_model_path)
# Out:
# Training started
# Epoch: 1/8 -  - Step: 60/3696 Training Loss: 3.522 -
# Epoch: 1/8 -  - Step: 117/3696 Training Loss: 3.390 -
# Epoch: 1/8 -  - Step: 181/3696 Training Loss: 3.436 -
# Epoch: 1/8 -  - Step: 244/3696 Training Loss: 3.440 -
# Epoch: 1/8 -  - Step: 306/3696 Training Loss: 3.397 -
# Epoch: 1/8 -  - Step: 364/3696 Training Loss: 3.492 -
# Epoch: 1/8 -  - Step: 423/3696 Training Loss: 3.406 -
# Epoch: 1/8 -  - Step: 481/3696 Training Loss: 3.394 -
# Epoch: 1/8 -  - Step: 542/3696 Training Loss: 3.470 -
# Epoch: 1/8 -  - Step: 602/3696 Training Loss: 3.429 -
# Epoch: 1/8 -  - Step: 657/3696 Training Loss: 3.410 -
# Epoch: 1/8 -  - Step: 714/3696 Training Loss: 3.510 -
# Epoch: 1/8 -  - Step: 784/3696 Training Loss: 3.419 -
# Epoch: 1/8 -  - Step: 848/3696 Training Loss: 3.442 -
# Epoch: 1/8 -  - Step: 904/3696 Training Loss: 3.414 -
# Epoch: 1/8 -  - Step: 962/3696 Training Loss: 3.399 -
# Epoch: 1/8 -  - Step: 1026/3696 Training Loss: 3.383 -
# Epoch: 1/8 -  - Step: 1085/3696 Training Loss: 3.413 -
# Epoch: 1/8 -  - Step: 1142/3696 Training Loss: 3.388 -
# Epoch: 1/8 -  - Step: 1201/3696 Training Loss: 3.455 -
# Epoch: 1/8 -  - Step: 1265/3696 Training Loss: 3.409 -
# Epoch: 1/8 -  - Step: 1327/3696 Training Loss: 3.483 -
# Epoch: 1/8 -  - Step: 1392/3696 Training Loss: 3.442 -
# Epoch: 1/8 -  - Step: 1452/3696 Training Loss: 3.408 -
# Epoch: 1/8 -  - Step: 1515/3696 Training Loss: 3.429 -
# Epoch: 1/8 -  - Step: 1581/3696 Training Loss: 3.388 -
# Epoch: 1/8 -  - Step: 1648/3696 Training Loss: 3.394 -
# Epoch: 1/8 -  - Step: 1705/3696 Training Loss: 3.457 -
# Epoch: 1/8 -  - Step: 1771/3696 Training Loss: 3.429 -
# Epoch: 1/8 - Training Loss: 3.4275084540049234 - Validation Loss: 3.406027105852807 - Train Accuracy:  0.03799999877810478 - Validation Accuracy:  0.032871972769498825
# Epoch: 1/8 -  - Step: 1892/3696 Training Loss: 6.781 -
# Epoch: 1/8 -  - Step: 1952/3696 Training Loss: 3.418 -
# Epoch: 1/8 -  - Step: 2012/3696 Training Loss: 3.417 -
# Epoch: 1/8 -  - Step: 2078/3696 Training Loss: 3.419 -
# Epoch: 1/8 -  - Step: 2135/3696 Training Loss: 3.432 -
# Epoch: 1/8 -  - Step: 2199/3696 Training Loss: 3.377 -
# Epoch: 1/8 -  - Step: 2259/3696 Training Loss: 3.412 -
# Epoch: 1/8 -  - Step: 2317/3696 Training Loss: 3.419 -
# Epoch: 1/8 -  - Step: 2377/3696 Training Loss: 3.381 -
# Epoch: 1/8 -  - Step: 2436/3696 Training Loss: 3.395 -
# Epoch: 1/8 -  - Step: 2499/3696 Training Loss: 3.395 -
# Epoch: 1/8 -  - Step: 2560/3696 Training Loss: 3.415 -
# Epoch: 1/8 -  - Step: 2621/3696 Training Loss: 3.433 -
# Epoch: 1/8 -  - Step: 2681/3696 Training Loss: 3.440 -
# Epoch: 1/8 -  - Step: 2740/3696 Training Loss: 3.403 -
# Epoch: 1/8 -  - Step: 2798/3696 Training Loss: 3.452 -
# Epoch: 1/8 -  - Step: 2862/3696 Training Loss: 3.418 -
# Epoch: 1/8 -  - Step: 2923/3696 Training Loss: 3.404 -
# Epoch: 1/8 -  - Step: 2992/3696 Training Loss: 3.401 -
# Epoch: 1/8 -  - Step: 3057/3696 Training Loss: 3.415 -
# Epoch: 1/8 -  - Step: 3124/3696 Training Loss: 3.432 -
# Epoch: 1/8 -  - Step: 3191/3696 Training Loss: 3.433 -
# Epoch: 1/8 -  - Step: 3259/3696 Training Loss: 3.420 -
# Epoch: 1/8 -  - Step: 3324/3696 Training Loss: 3.396 -
# Epoch: 1/8 -  - Step: 3386/3696 Training Loss: 3.421 -
# Epoch: 1/8 -  - Step: 3451/3696 Training Loss: 3.409 -
# Epoch: 1/8 -  - Step: 3508/3696 Training Loss: 3.453 -
# Epoch: 1/8 -  - Step: 3566/3696 Training Loss: 3.373 -
# Epoch: 1/8 -  - Step: 3625/3696 Training Loss: 3.412 -
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type BaselineModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type cnn. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type fpm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type attention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch: 2/8 - Training Loss: 3.413387210051219 - Validation Loss: 3.406470665469714 - Train Accuracy:  0.030666666105389595 - Validation Accuracy:  0.034602075815200806
# Epoch: 2/8 -  - Step: 65/3696 Training Loss: 6.822 -
# Epoch: 2/8 -  - Step: 123/3696 Training Loss: 3.407 -
# Epoch: 2/8 -  - Step: 192/3696 Training Loss: 3.383 -
# Epoch: 2/8 -  - Step: 254/3696 Training Loss: 3.446 -
# Epoch: 2/8 -  - Step: 319/3696 Training Loss: 3.420 -
# Epoch: 2/8 -  - Step: 378/3696 Training Loss: 3.422 -
# Epoch: 2/8 -  - Step: 446/3696 Training Loss: 3.419 -
# Epoch: 2/8 -  - Step: 506/3696 Training Loss: 3.400 -
# Epoch: 2/8 -  - Step: 567/3696 Training Loss: 3.383 -
# Epoch: 2/8 -  - Step: 628/3696 Training Loss: 3.440 -
# Epoch: 2/8 -  - Step: 694/3696 Training Loss: 3.404 -
# Epoch: 2/8 -  - Step: 760/3696 Training Loss: 3.383 -
# Epoch: 2/8 -  - Step: 822/3696 Training Loss: 3.371 -
# Epoch: 2/8 -  - Step: 883/3696 Training Loss: 3.443 -
# Epoch: 2/8 -  - Step: 951/3696 Training Loss: 3.415 -
# Epoch: 2/8 -  - Step: 1007/3696 Training Loss: 3.412 -
# Epoch: 2/8 -  - Step: 1067/3696 Training Loss: 3.402 -
# Epoch: 2/8 -  - Step: 1132/3696 Training Loss: 3.442 -
# Epoch: 2/8 -  - Step: 1189/3696 Training Loss: 3.420 -
# Epoch: 2/8 -  - Step: 1246/3696 Training Loss: 3.441 -
# Epoch: 2/8 -  - Step: 1302/3696 Training Loss: 3.382 -
# Epoch: 2/8 -  - Step: 1364/3696 Training Loss: 3.359 -
# Epoch: 2/8 -  - Step: 1430/3696 Training Loss: 3.402 -
# Epoch: 2/8 -  - Step: 1490/3696 Training Loss: 3.386 -
# Epoch: 2/8 -  - Step: 1556/3696 Training Loss: 3.313 -
# Epoch: 2/8 -  - Step: 1613/3696 Training Loss: 3.406 -
# Epoch: 2/8 -  - Step: 1672/3696 Training Loss: 3.369 -
# Epoch: 2/8 -  - Step: 1737/3696 Training Loss: 3.407 -
# Epoch: 2/8 -  - Step: 1797/3696 Training Loss: 3.420 -
# Epoch: 2/8 - Training Loss: 3.4028521995544434 - Validation Loss: 3.362564873117889 - Train Accuracy:  0.03866666555404663 - Validation Accuracy:  0.032871972769498825
# Epoch: 2/8 -  - Step: 1928/3696 Training Loss: 6.739 -
# Epoch: 2/8 -  - Step: 1990/3696 Training Loss: 3.373 -
# Epoch: 2/8 -  - Step: 2046/3696 Training Loss: 3.403 -
# Epoch: 2/8 -  - Step: 2104/3696 Training Loss: 3.317 -
# Epoch: 2/8 -  - Step: 2171/3696 Training Loss: 3.362 -
# Epoch: 2/8 -  - Step: 2232/3696 Training Loss: 3.337 -
# Epoch: 2/8 -  - Step: 2293/3696 Training Loss: 3.410 -
# Epoch: 2/8 -  - Step: 2353/3696 Training Loss: 3.353 -
# Epoch: 2/8 -  - Step: 2415/3696 Training Loss: 3.308 -
# Epoch: 2/8 -  - Step: 2472/3696 Training Loss: 3.346 -
# Epoch: 2/8 -  - Step: 2530/3696 Training Loss: 3.337 -
# Epoch: 2/8 -  - Step: 2592/3696 Training Loss: 3.274 -
# Epoch: 2/8 -  - Step: 2656/3696 Training Loss: 3.375 -
# Epoch: 2/8 -  - Step: 2713/3696 Training Loss: 3.271 -
# Epoch: 2/8 -  - Step: 2779/3696 Training Loss: 3.359 -
# Epoch: 2/8 -  - Step: 2839/3696 Training Loss: 3.318 -
# Epoch: 2/8 -  - Step: 2895/3696 Training Loss: 3.228 -
# Epoch: 2/8 -  - Step: 2965/3696 Training Loss: 3.211 -
# Epoch: 2/8 -  - Step: 3024/3696 Training Loss: 3.380 -
# Epoch: 2/8 -  - Step: 3089/3696 Training Loss: 3.225 -
# Epoch: 2/8 -  - Step: 3152/3696 Training Loss: 3.186 -
# Epoch: 2/8 -  - Step: 3220/3696 Training Loss: 3.251 -
# Epoch: 2/8 -  - Step: 3286/3696 Training Loss: 3.217 -
# Epoch: 2/8 -  - Step: 3354/3696 Training Loss: 3.194 -
# Epoch: 2/8 -  - Step: 3410/3696 Training Loss: 3.286 -
# Epoch: 2/8 -  - Step: 3468/3696 Training Loss: 3.333 -
# Epoch: 2/8 -  - Step: 3531/3696 Training Loss: 3.182 -
# Epoch: 2/8 -  - Step: 3587/3696 Training Loss: 3.178 -
# Epoch: 2/8 -  - Step: 3641/3696 Training Loss: 3.025 -
# Epoch: 3/8 - Training Loss: 3.28398881705602 - Validation Loss: 3.099327887218304 - Train Accuracy:  0.0573333315551281 - Validation Accuracy:  0.05709342658519745
# Epoch: 3/8 -  - Step: 60/3696 Training Loss: 6.160 -
# Epoch: 3/8 -  - Step: 118/3696 Training Loss: 3.153 -
# Epoch: 3/8 -  - Step: 179/3696 Training Loss: 3.200 -
# Epoch: 3/8 -  - Step: 239/3696 Training Loss: 3.070 -
# Epoch: 3/8 -  - Step: 299/3696 Training Loss: 2.930 -
# Epoch: 3/8 -  - Step: 360/3696 Training Loss: 3.139 -
# Epoch: 3/8 -  - Step: 424/3696 Training Loss: 3.051 -
# Epoch: 3/8 -  - Step: 490/3696 Training Loss: 3.170 -
# Epoch: 3/8 -  - Step: 554/3696 Training Loss: 3.108 -
# Epoch: 3/8 -  - Step: 620/3696 Training Loss: 3.219 -
# Epoch: 3/8 -  - Step: 678/3696 Training Loss: 3.206 -
# Epoch: 3/8 -  - Step: 734/3696 Training Loss: 3.265 -
# Epoch: 3/8 -  - Step: 792/3696 Training Loss: 3.110 -
# Epoch: 3/8 -  - Step: 854/3696 Training Loss: 3.143 -
# Epoch: 3/8 -  - Step: 912/3696 Training Loss: 3.077 -
# Epoch: 3/8 -  - Step: 978/3696 Training Loss: 3.122 -
# Epoch: 3/8 -  - Step: 1033/3696 Training Loss: 2.986 -
# Epoch: 3/8 -  - Step: 1092/3696 Training Loss: 3.044 -
# Epoch: 3/8 -  - Step: 1159/3696 Training Loss: 3.158 -
# Epoch: 3/8 -  - Step: 1217/3696 Training Loss: 3.133 -
# Epoch: 3/8 -  - Step: 1279/3696 Training Loss: 3.006 -
# Epoch: 3/8 -  - Step: 1344/3696 Training Loss: 3.088 -
# Epoch: 3/8 -  - Step: 1404/3696 Training Loss: 3.233 -
# Epoch: 3/8 -  - Step: 1471/3696 Training Loss: 3.085 -
# Epoch: 3/8 -  - Step: 1543/3696 Training Loss: 3.096 -
# Epoch: 3/8 -  - Step: 1601/3696 Training Loss: 2.905 -
# Epoch: 3/8 -  - Step: 1672/3696 Training Loss: 3.041 -
# Epoch: 3/8 -  - Step: 1737/3696 Training Loss: 2.928 -
# Epoch: 3/8 -  - Step: 1798/3696 Training Loss: 2.995 -
# Epoch: 3/8 - Training Loss: 3.0901791133880616 - Validation Loss: 2.941793518701639 - Train Accuracy:  0.09533333033323288 - Validation Accuracy:  0.10207612812519073
# Epoch: 3/8 -  - Step: 1920/3696 Training Loss: 6.162 -
# Epoch: 3/8 -  - Step: 1977/3696 Training Loss: 2.979 -
# Epoch: 3/8 -  - Step: 2043/3696 Training Loss: 2.967 -
# Epoch: 3/8 -  - Step: 2106/3696 Training Loss: 2.932 -
# Epoch: 3/8 -  - Step: 2164/3696 Training Loss: 3.077 -
# Epoch: 3/8 -  - Step: 2236/3696 Training Loss: 2.914 -
# Epoch: 3/8 -  - Step: 2292/3696 Training Loss: 3.023 -
# Epoch: 3/8 -  - Step: 2350/3696 Training Loss: 3.015 -
# Epoch: 3/8 -  - Step: 2419/3696 Training Loss: 3.058 -
# Epoch: 3/8 -  - Step: 2477/3696 Training Loss: 3.056 -
# Epoch: 3/8 -  - Step: 2540/3696 Training Loss: 3.023 -
# Epoch: 3/8 -  - Step: 2611/3696 Training Loss: 2.878 -
# Epoch: 3/8 -  - Step: 2673/3696 Training Loss: 3.006 -
# Epoch: 3/8 -  - Step: 2733/3696 Training Loss: 2.950 -
# Epoch: 3/8 -  - Step: 2796/3696 Training Loss: 2.934 -
# Epoch: 3/8 -  - Step: 2858/3696 Training Loss: 2.977 -
# Epoch: 3/8 -  - Step: 2917/3696 Training Loss: 2.908 -
# Epoch: 3/8 -  - Step: 2980/3696 Training Loss: 2.925 -
# Epoch: 3/8 -  - Step: 3039/3696 Training Loss: 2.796 -
# Epoch: 3/8 -  - Step: 3096/3696 Training Loss: 2.870 -
# Epoch: 3/8 -  - Step: 3156/3696 Training Loss: 2.684 -
# Epoch: 3/8 -  - Step: 3210/3696 Training Loss: 3.084 -
# Epoch: 3/8 -  - Step: 3270/3696 Training Loss: 2.804 -
# Epoch: 3/8 -  - Step: 3330/3696 Training Loss: 2.981 -
# Epoch: 3/8 -  - Step: 3385/3696 Training Loss: 2.794 -
# Epoch: 3/8 -  - Step: 3445/3696 Training Loss: 2.814 -
# Epoch: 3/8 -  - Step: 3513/3696 Training Loss: 2.865 -
# Epoch: 3/8 -  - Step: 3576/3696 Training Loss: 2.772 -
# Epoch: 3/8 -  - Step: 3638/3696 Training Loss: 2.804 -
# Epoch: 4/8 - Training Loss: 2.929512109518051 - Validation Loss: 2.773176353489239 - Train Accuracy:  0.15000000596046448 - Validation Accuracy:  0.17993079125881195
# Epoch: 4/8 -  - Step: 74/3696 Training Loss: 5.684 -
# Epoch: 4/8 -  - Step: 136/3696 Training Loss: 2.628 -
# Epoch: 4/8 -  - Step: 194/3696 Training Loss: 2.713 -
# Epoch: 4/8 -  - Step: 260/3696 Training Loss: 2.608 -
# Epoch: 4/8 -  - Step: 320/3696 Training Loss: 2.732 -
# Epoch: 4/8 -  - Step: 382/3696 Training Loss: 2.738 -
# Epoch: 4/8 -  - Step: 445/3696 Training Loss: 2.728 -
# Epoch: 4/8 -  - Step: 507/3696 Training Loss: 2.650 -
# Epoch: 4/8 -  - Step: 564/3696 Training Loss: 2.765 -
# Epoch: 4/8 -  - Step: 626/3696 Training Loss: 2.568 -
# Epoch: 4/8 -  - Step: 683/3696 Training Loss: 2.635 -
# Epoch: 4/8 -  - Step: 742/3696 Training Loss: 2.679 -
# Epoch: 4/8 -  - Step: 806/3696 Training Loss: 2.571 -
# Epoch: 4/8 -  - Step: 872/3696 Training Loss: 2.512 -
# Epoch: 4/8 -  - Step: 939/3696 Training Loss: 2.634 -
# Epoch: 4/8 -  - Step: 996/3696 Training Loss: 2.925 -
# Epoch: 4/8 -  - Step: 1057/3696 Training Loss: 2.632 -
# Epoch: 4/8 -  - Step: 1114/3696 Training Loss: 2.741 -
# Epoch: 4/8 -  - Step: 1186/3696 Training Loss: 2.632 -
# Epoch: 4/8 -  - Step: 1248/3696 Training Loss: 2.633 -
# Epoch: 4/8 -  - Step: 1314/3696 Training Loss: 2.747 -
# Epoch: 4/8 -  - Step: 1377/3696 Training Loss: 2.592 -
# Epoch: 4/8 -  - Step: 1437/3696 Training Loss: 2.583 -
# Epoch: 4/8 -  - Step: 1498/3696 Training Loss: 2.628 -
# Epoch: 4/8 -  - Step: 1554/3696 Training Loss: 2.572 -
# Epoch: 4/8 -  - Step: 1609/3696 Training Loss: 2.745 -
# Epoch: 4/8 -  - Step: 1671/3696 Training Loss: 2.741 -
# Epoch: 4/8 -  - Step: 1733/3696 Training Loss: 2.764 -
# Epoch: 4/8 -  - Step: 1793/3696 Training Loss: 2.555 -
# Epoch: 4/8 - Training Loss: 2.670778840303421 - Validation Loss: 2.810118042680219 - Train Accuracy:  0.21199999749660492 - Validation Accuracy:  0.22318339347839355
# Epoch: 4/8 -  - Step: 1916/3696 Training Loss: 5.324 -
# Epoch: 4/8 -  - Step: 1984/3696 Training Loss: 2.613 -
# Epoch: 4/8 -  - Step: 2042/3696 Training Loss: 2.667 -
# Epoch: 4/8 -  - Step: 2108/3696 Training Loss: 2.569 -
# Epoch: 4/8 -  - Step: 2169/3696 Training Loss: 2.483 -
# Epoch: 4/8 -  - Step: 2232/3696 Training Loss: 2.462 -
# Epoch: 4/8 -  - Step: 2293/3696 Training Loss: 2.547 -
# Epoch: 4/8 -  - Step: 2355/3696 Training Loss: 2.524 -
# Epoch: 4/8 -  - Step: 2418/3696 Training Loss: 2.495 -
# Epoch: 4/8 -  - Step: 2475/3696 Training Loss: 2.570 -
# Epoch: 4/8 -  - Step: 2539/3696 Training Loss: 2.676 -
# Epoch: 4/8 -  - Step: 2603/3696 Training Loss: 2.488 -
# Epoch: 4/8 -  - Step: 2666/3696 Training Loss: 2.670 -
# Epoch: 4/8 -  - Step: 2735/3696 Training Loss: 2.375 -
# Epoch: 4/8 -  - Step: 2795/3696 Training Loss: 2.495 -
# Epoch: 4/8 -  - Step: 2852/3696 Training Loss: 2.575 -
# Epoch: 4/8 -  - Step: 2910/3696 Training Loss: 2.815 -
# Epoch: 4/8 -  - Step: 2968/3696 Training Loss: 2.545 -
# Epoch: 4/8 -  - Step: 3031/3696 Training Loss: 2.583 -
# Epoch: 4/8 -  - Step: 3095/3696 Training Loss: 2.808 -
# Epoch: 4/8 -  - Step: 3155/3696 Training Loss: 2.530 -
# Epoch: 4/8 -  - Step: 3213/3696 Training Loss: 2.459 -
# Epoch: 4/8 -  - Step: 3274/3696 Training Loss: 2.464 -
# Epoch: 4/8 -  - Step: 3341/3696 Training Loss: 2.387 -
# Epoch: 4/8 -  - Step: 3395/3696 Training Loss: 2.647 -
# Epoch: 4/8 -  - Step: 3456/3696 Training Loss: 2.414 -
# Epoch: 4/8 -  - Step: 3511/3696 Training Loss: 2.625 -
# Epoch: 4/8 -  - Step: 3574/3696 Training Loss: 2.421 -
# Epoch: 4/8 -  - Step: 3639/3696 Training Loss: 2.548 -
# Epoch: 5/8 - Training Loss: 2.5494045193195345 - Validation Loss: 2.7258331759165726 - Train Accuracy:  0.23999999463558197 - Validation Accuracy:  0.23183390498161316
# Epoch: 5/8 -  - Step: 70/3696 Training Loss: 4.673 -
# Epoch: 5/8 -  - Step: 127/3696 Training Loss: 2.494 -
# Epoch: 5/8 -  - Step: 189/3696 Training Loss: 2.585 -
# Epoch: 5/8 -  - Step: 244/3696 Training Loss: 2.186 -
# Epoch: 5/8 -  - Step: 308/3696 Training Loss: 2.473 -
# Epoch: 5/8 -  - Step: 372/3696 Training Loss: 2.402 -
# Epoch: 5/8 -  - Step: 433/3696 Training Loss: 2.413 -
# Epoch: 5/8 -  - Step: 489/3696 Training Loss: 2.340 -
# Epoch: 5/8 -  - Step: 553/3696 Training Loss: 2.496 -
# Epoch: 5/8 -  - Step: 620/3696 Training Loss: 2.201 -
# Epoch: 5/8 -  - Step: 683/3696 Training Loss: 2.520 -
# Epoch: 5/8 -  - Step: 747/3696 Training Loss: 2.330 -
# Epoch: 5/8 -  - Step: 800/3696 Training Loss: 2.427 -
# Epoch: 5/8 -  - Step: 861/3696 Training Loss: 2.565 -
# Epoch: 5/8 -  - Step: 914/3696 Training Loss: 2.369 -
# Epoch: 5/8 -  - Step: 978/3696 Training Loss: 2.209 -
# Epoch: 5/8 -  - Step: 1035/3696 Training Loss: 2.471 -
# Epoch: 5/8 -  - Step: 1100/3696 Training Loss: 2.537 -
# Epoch: 5/8 -  - Step: 1160/3696 Training Loss: 2.002 -
# Epoch: 5/8 -  - Step: 1223/3696 Training Loss: 2.541 -
# Epoch: 5/8 -  - Step: 1283/3696 Training Loss: 2.282 -
# Epoch: 5/8 -  - Step: 1343/3696 Training Loss: 2.427 -
# Epoch: 5/8 -  - Step: 1410/3696 Training Loss: 2.538 -
# Epoch: 5/8 -  - Step: 1480/3696 Training Loss: 2.376 -
# Epoch: 5/8 -  - Step: 1545/3696 Training Loss: 2.361 -
# Epoch: 5/8 -  - Step: 1603/3696 Training Loss: 2.320 -
# Epoch: 5/8 -  - Step: 1667/3696 Training Loss: 2.122 -
# Epoch: 5/8 -  - Step: 1731/3696 Training Loss: 2.059 -
# Epoch: 5/8 -  - Step: 1790/3696 Training Loss: 2.262 -
# Epoch: 5/8 - Training Loss: 2.356506801843643 - Validation Loss: 2.858374418065622 - Train Accuracy:  0.3059999942779541 - Validation Accuracy:  0.2456747442483902
# Epoch: 5/8 -  - Step: 1911/3696 Training Loss: 4.603 -
# Epoch: 5/8 -  - Step: 1968/3696 Training Loss: 1.955 -
# Epoch: 5/8 -  - Step: 2025/3696 Training Loss: 2.360 -
# Epoch: 5/8 -  - Step: 2083/3696 Training Loss: 2.386 -
# Epoch: 5/8 -  - Step: 2141/3696 Training Loss: 2.554 -
# Epoch: 5/8 -  - Step: 2201/3696 Training Loss: 2.437 -
# Epoch: 5/8 -  - Step: 2259/3696 Training Loss: 2.636 -
# Epoch: 5/8 -  - Step: 2325/3696 Training Loss: 2.382 -
# Epoch: 5/8 -  - Step: 2383/3696 Training Loss: 2.551 -
# Epoch: 5/8 -  - Step: 2451/3696 Training Loss: 2.362 -
# Epoch: 5/8 -  - Step: 2512/3696 Training Loss: 2.233 -
# Epoch: 5/8 -  - Step: 2576/3696 Training Loss: 2.402 -
# Epoch: 5/8 -  - Step: 2646/3696 Training Loss: 2.175 -
# Epoch: 5/8 -  - Step: 2706/3696 Training Loss: 2.111 -
# Epoch: 5/8 -  - Step: 2767/3696 Training Loss: 2.395 -
# Epoch: 5/8 -  - Step: 2827/3696 Training Loss: 2.214 -
# Epoch: 5/8 -  - Step: 2896/3696 Training Loss: 2.402 -
# Epoch: 5/8 -  - Step: 2953/3696 Training Loss: 2.221 -
# Epoch: 5/8 -  - Step: 3013/3696 Training Loss: 2.368 -
# Epoch: 5/8 -  - Step: 3071/3696 Training Loss: 2.236 -
# Epoch: 5/8 -  - Step: 3136/3696 Training Loss: 2.424 -
# Epoch: 5/8 -  - Step: 3204/3696 Training Loss: 2.301 -
# Epoch: 5/8 -  - Step: 3263/3696 Training Loss: 2.314 -
# Epoch: 5/8 -  - Step: 3326/3696 Training Loss: 1.981 -
# Epoch: 5/8 -  - Step: 3396/3696 Training Loss: 2.443 -
# Epoch: 5/8 -  - Step: 3460/3696 Training Loss: 2.406 -
# Epoch: 5/8 -  - Step: 3520/3696 Training Loss: 2.392 -
# Epoch: 5/8 -  - Step: 3582/3696 Training Loss: 2.284 -
# Epoch: 5/8 -  - Step: 3648/3696 Training Loss: 2.538 -
# Epoch: 6/8 - Training Loss: 2.3489311288197836 - Validation Loss: 2.719084726897903 - Train Accuracy:  0.30399999022483826 - Validation Accuracy:  0.2370242178440094
# Epoch: 6/8 -  - Step: 80/3696 Training Loss: 4.653 -
# Epoch: 6/8 -  - Step: 138/3696 Training Loss: 2.219 -
# Epoch: 6/8 -  - Step: 199/3696 Training Loss: 2.263 -
# Epoch: 6/8 -  - Step: 261/3696 Training Loss: 1.962 -
# Epoch: 6/8 -  - Step: 328/3696 Training Loss: 2.282 -
# Epoch: 6/8 -  - Step: 387/3696 Training Loss: 2.088 -
# Epoch: 6/8 -  - Step: 455/3696 Training Loss: 2.181 -
# Epoch: 6/8 -  - Step: 514/3696 Training Loss: 2.111 -
# Epoch: 6/8 -  - Step: 578/3696 Training Loss: 2.489 -
# Epoch: 6/8 -  - Step: 634/3696 Training Loss: 2.417 -
# Epoch: 6/8 -  - Step: 694/3696 Training Loss: 2.386 -
# Epoch: 6/8 -  - Step: 759/3696 Training Loss: 2.207 -
# Epoch: 6/8 -  - Step: 821/3696 Training Loss: 2.119 -
# Epoch: 6/8 -  - Step: 881/3696 Training Loss: 2.317 -
# Epoch: 6/8 -  - Step: 940/3696 Training Loss: 2.692 -
# Epoch: 6/8 -  - Step: 1001/3696 Training Loss: 2.036 -
# Epoch: 6/8 -  - Step: 1062/3696 Training Loss: 2.158 -
# Epoch: 6/8 -  - Step: 1118/3696 Training Loss: 2.112 -
# Epoch: 6/8 -  - Step: 1180/3696 Training Loss: 2.379 -
# Epoch: 6/8 -  - Step: 1242/3696 Training Loss: 2.519 -
# Epoch: 6/8 -  - Step: 1310/3696 Training Loss: 2.177 -
# Epoch: 6/8 -  - Step: 1373/3696 Training Loss: 2.178 -
# Epoch: 6/8 -  - Step: 1433/3696 Training Loss: 2.134 -
# Epoch: 6/8 -  - Step: 1501/3696 Training Loss: 2.049 -
# Epoch: 6/8 -  - Step: 1563/3696 Training Loss: 2.376 -
# Epoch: 6/8 -  - Step: 1621/3696 Training Loss: 2.128 -
# Epoch: 6/8 -  - Step: 1682/3696 Training Loss: 2.255 -
# Epoch: 6/8 -  - Step: 1742/3696 Training Loss: 2.219 -
# Epoch: 6/8 -  - Step: 1800/3696 Training Loss: 2.165 -
# Epoch: 6/8 - Training Loss: 2.2277511694431307 - Validation Loss: 2.8358739040095915 - Train Accuracy:  0.34066668152809143 - Validation Accuracy:  0.2871972322463989
# Epoch: 6/8 -  - Step: 1920/3696 Training Loss: 3.925 -
# Epoch: 6/8 -  - Step: 1985/3696 Training Loss: 2.055 -
# Epoch: 6/8 -  - Step: 2046/3696 Training Loss: 1.966 -
# Epoch: 6/8 -  - Step: 2100/3696 Training Loss: 1.933 -
# Epoch: 6/8 -  - Step: 2162/3696 Training Loss: 2.228 -
# Epoch: 6/8 -  - Step: 2223/3696 Training Loss: 2.090 -
# Epoch: 6/8 -  - Step: 2287/3696 Training Loss: 2.087 -
# Epoch: 6/8 -  - Step: 2355/3696 Training Loss: 1.948 -
# Epoch: 6/8 -  - Step: 2415/3696 Training Loss: 1.946 -
# Epoch: 6/8 -  - Step: 2480/3696 Training Loss: 2.212 -
# Epoch: 6/8 -  - Step: 2536/3696 Training Loss: 1.881 -
# Epoch: 6/8 -  - Step: 2599/3696 Training Loss: 2.293 -
# Epoch: 6/8 -  - Step: 2674/3696 Training Loss: 1.799 -
# Epoch: 6/8 -  - Step: 2737/3696 Training Loss: 2.262 -
# Epoch: 6/8 -  - Step: 2797/3696 Training Loss: 1.948 -
# Epoch: 6/8 -  - Step: 2861/3696 Training Loss: 2.333 -
# Epoch: 6/8 -  - Step: 2927/3696 Training Loss: 2.038 -
# Epoch: 6/8 -  - Step: 2981/3696 Training Loss: 2.172 -
# Epoch: 6/8 -  - Step: 3035/3696 Training Loss: 2.184 -
# Epoch: 6/8 -  - Step: 3093/3696 Training Loss: 2.069 -
# Epoch: 6/8 -  - Step: 3153/3696 Training Loss: 1.729 -
# Epoch: 6/8 -  - Step: 3217/3696 Training Loss: 2.184 -
# Epoch: 6/8 -  - Step: 3277/3696 Training Loss: 2.062 -
# Epoch: 6/8 -  - Step: 3346/3696 Training Loss: 1.894 -
# Epoch: 6/8 -  - Step: 3404/3696 Training Loss: 2.135 -
# Epoch: 6/8 -  - Step: 3458/3696 Training Loss: 2.207 -
# Epoch: 6/8 -  - Step: 3518/3696 Training Loss: 1.844 -
# Epoch: 6/8 -  - Step: 3582/3696 Training Loss: 2.076 -
# Epoch: 6/8 -  - Step: 3644/3696 Training Loss: 2.282 -
# Epoch: 7/8 - Training Loss: 2.06606706794103 - Validation Loss: 2.990603025190558 - Train Accuracy:  0.40933331847190857 - Validation Accuracy:  0.2785467207431793
# Epoch: 7/8 -  - Step: 75/3696 Training Loss: 4.392 -
# Epoch: 7/8 -  - Step: 147/3696 Training Loss: 2.156 -
# Epoch: 7/8 -  - Step: 210/3696 Training Loss: 2.065 -
# Epoch: 7/8 -  - Step: 279/3696 Training Loss: 2.063 -
# Epoch: 7/8 -  - Step: 343/3696 Training Loss: 2.084 -
# Epoch: 7/8 -  - Step: 400/3696 Training Loss: 1.979 -
# Epoch: 7/8 -  - Step: 457/3696 Training Loss: 1.924 -
# Epoch: 7/8 -  - Step: 515/3696 Training Loss: 1.847 -
# Epoch: 7/8 -  - Step: 575/3696 Training Loss: 1.939 -
# Epoch: 7/8 -  - Step: 633/3696 Training Loss: 2.118 -
# Epoch: 7/8 -  - Step: 695/3696 Training Loss: 2.289 -
# Epoch: 7/8 -  - Step: 759/3696 Training Loss: 2.216 -
# Epoch: 7/8 -  - Step: 820/3696 Training Loss: 1.946 -
# Epoch: 7/8 -  - Step: 880/3696 Training Loss: 1.978 -
# Epoch: 7/8 -  - Step: 940/3696 Training Loss: 2.062 -
# Epoch: 7/8 -  - Step: 998/3696 Training Loss: 2.129 -
# Epoch: 7/8 -  - Step: 1060/3696 Training Loss: 1.692 -
# Epoch: 7/8 -  - Step: 1117/3696 Training Loss: 2.466 -
# Epoch: 7/8 -  - Step: 1175/3696 Training Loss: 2.032 -
# Epoch: 7/8 -  - Step: 1245/3696 Training Loss: 2.226 -
# Epoch: 7/8 -  - Step: 1308/3696 Training Loss: 1.912 -
# Epoch: 7/8 -  - Step: 1369/3696 Training Loss: 1.927 -
# Epoch: 7/8 -  - Step: 1424/3696 Training Loss: 1.851 -
# Epoch: 7/8 -  - Step: 1483/3696 Training Loss: 2.244 -
# Epoch: 7/8 -  - Step: 1549/3696 Training Loss: 1.857 -
# Epoch: 7/8 -  - Step: 1609/3696 Training Loss: 2.230 -
# Epoch: 7/8 -  - Step: 1673/3696 Training Loss: 1.810 -
# Epoch: 7/8 -  - Step: 1737/3696 Training Loss: 1.827 -
# Epoch: 7/8 -  - Step: 1795/3696 Training Loss: 1.777 -
# Epoch: 7/8 - Training Loss: 2.027128399848938 - Validation Loss: 3.19546358869975 - Train Accuracy:  0.40933331847190857 - Validation Accuracy:  0.2975778579711914
# Epoch: 7/8 -  - Step: 1918/3696 Training Loss: 4.286 -
# Epoch: 7/8 -  - Step: 1977/3696 Training Loss: 1.949 -
# Epoch: 7/8 -  - Step: 2041/3696 Training Loss: 1.972 -
# Epoch: 7/8 -  - Step: 2107/3696 Training Loss: 2.190 -
# Epoch: 7/8 -  - Step: 2169/3696 Training Loss: 2.215 -
# Epoch: 7/8 -  - Step: 2233/3696 Training Loss: 1.985 -
# Epoch: 7/8 -  - Step: 2295/3696 Training Loss: 1.977 -
# Epoch: 7/8 -  - Step: 2355/3696 Training Loss: 1.993 -
# Epoch: 7/8 -  - Step: 2415/3696 Training Loss: 1.742 -
# Epoch: 7/8 -  - Step: 2481/3696 Training Loss: 2.295 -
# Epoch: 7/8 -  - Step: 2544/3696 Training Loss: 2.063 -
# Epoch: 7/8 -  - Step: 2603/3696 Training Loss: 2.064 -
# Epoch: 7/8 -  - Step: 2664/3696 Training Loss: 1.970 -
# Epoch: 7/8 -  - Step: 2724/3696 Training Loss: 1.819 -
# Epoch: 7/8 -  - Step: 2788/3696 Training Loss: 2.015 -
# Epoch: 7/8 -  - Step: 2849/3696 Training Loss: 1.836 -
# Epoch: 7/8 -  - Step: 2915/3696 Training Loss: 2.100 -
# Epoch: 7/8 -  - Step: 2980/3696 Training Loss: 1.845 -
# Epoch: 7/8 -  - Step: 3044/3696 Training Loss: 2.087 -
# Epoch: 7/8 -  - Step: 3108/3696 Training Loss: 2.081 -
# Epoch: 7/8 -  - Step: 3166/3696 Training Loss: 1.760 -
# Epoch: 7/8 -  - Step: 3228/3696 Training Loss: 1.891 -
# Epoch: 7/8 -  - Step: 3295/3696 Training Loss: 2.123 -
# Epoch: 7/8 -  - Step: 3354/3696 Training Loss: 1.701 -
# Epoch: 7/8 -  - Step: 3415/3696 Training Loss: 1.705 -
# Epoch: 7/8 -  - Step: 3472/3696 Training Loss: 2.377 -
# Epoch: 7/8 -  - Step: 3531/3696 Training Loss: 1.868 -
# Epoch: 7/8 -  - Step: 3592/3696 Training Loss: 2.175 -
# Epoch: 7/8 -  - Step: 3650/3696 Training Loss: 2.001 -
# Epoch: 8/8 - Training Loss: 2.0019248915513357 - Validation Loss: 2.952748662666466 - Train Accuracy:  0.414000004529953 - Validation Accuracy:  0.30103805661201477
# Epoch: 8/8 -  - Step: 74/3696 Training Loss: 3.817 -
# Epoch: 8/8 -  - Step: 137/3696 Training Loss: 1.683 -
# Epoch: 8/8 -  - Step: 203/3696 Training Loss: 2.063 -
# Epoch: 8/8 -  - Step: 261/3696 Training Loss: 1.541 -
# Epoch: 8/8 -  - Step: 324/3696 Training Loss: 1.849 -
# Epoch: 8/8 -  - Step: 385/3696 Training Loss: 2.172 -
# Epoch: 8/8 -  - Step: 446/3696 Training Loss: 2.160 -
# Epoch: 8/8 -  - Step: 511/3696 Training Loss: 1.956 -
# Epoch: 8/8 -  - Step: 575/3696 Training Loss: 1.697 -
# Epoch: 8/8 -  - Step: 642/3696 Training Loss: 1.961 -
# Epoch: 8/8 -  - Step: 705/3696 Training Loss: 1.922 -
# Epoch: 8/8 -  - Step: 770/3696 Training Loss: 2.028 -
# Epoch: 8/8 -  - Step: 830/3696 Training Loss: 1.806 -
# Epoch: 8/8 -  - Step: 892/3696 Training Loss: 2.146 -
# Epoch: 8/8 -  - Step: 955/3696 Training Loss: 1.589 -
# Epoch: 8/8 -  - Step: 1014/3696 Training Loss: 1.520 -
# Epoch: 8/8 -  - Step: 1079/3696 Training Loss: 1.862 -
# Epoch: 8/8 -  - Step: 1147/3696 Training Loss: 1.853 -
# Epoch: 8/8 -  - Step: 1205/3696 Training Loss: 2.156 -
# Epoch: 8/8 -  - Step: 1265/3696 Training Loss: 1.618 -
# Epoch: 8/8 -  - Step: 1323/3696 Training Loss: 1.981 -
# Epoch: 8/8 -  - Step: 1384/3696 Training Loss: 2.137 -
# Epoch: 8/8 -  - Step: 1438/3696 Training Loss: 1.815 -
# Epoch: 8/8 -  - Step: 1501/3696 Training Loss: 2.078 -
# Epoch: 8/8 -  - Step: 1568/3696 Training Loss: 1.965 -
# Epoch: 8/8 -  - Step: 1627/3696 Training Loss: 1.884 -
# Epoch: 8/8 -  - Step: 1687/3696 Training Loss: 2.031 -
# Epoch: 8/8 -  - Step: 1748/3696 Training Loss: 2.155 -
# Epoch: 8/8 -  - Step: 1809/3696 Training Loss: 1.819 -
# Epoch: 8/8 - Training Loss: 1.893963763554891 - Validation Loss: 3.266668362497871 - Train Accuracy:  0.44466665387153625 - Validation Accuracy:  0.3096885681152344
# Epoch: 8/8 -  - Step: 1928/3696 Training Loss: 3.511 -
# Epoch: 8/8 -  - Step: 1994/3696 Training Loss: 1.994 -
# Epoch: 8/8 -  - Step: 2052/3696 Training Loss: 1.918 -
# Epoch: 8/8 -  - Step: 2116/3696 Training Loss: 2.089 -
# Epoch: 8/8 -  - Step: 2181/3696 Training Loss: 1.680 -
# Epoch: 8/8 -  - Step: 2242/3696 Training Loss: 1.791 -
# Epoch: 8/8 -  - Step: 2301/3696 Training Loss: 2.042 -
# Epoch: 8/8 -  - Step: 2361/3696 Training Loss: 1.743 -
# Epoch: 8/8 -  - Step: 2424/3696 Training Loss: 2.023 -
# Epoch: 8/8 -  - Step: 2485/3696 Training Loss: 1.862 -
# Epoch: 8/8 -  - Step: 2545/3696 Training Loss: 1.999 -
# Epoch: 8/8 -  - Step: 2604/3696 Training Loss: 1.605 -
# Epoch: 8/8 -  - Step: 2664/3696 Training Loss: 2.012 -
# Epoch: 8/8 -  - Step: 2720/3696 Training Loss: 1.505 -
# Epoch: 8/8 -  - Step: 2778/3696 Training Loss: 1.440 -
# Epoch: 8/8 -  - Step: 2840/3696 Training Loss: 1.872 -
# Epoch: 8/8 -  - Step: 2907/3696 Training Loss: 1.945 -
# Epoch: 8/8 -  - Step: 2970/3696 Training Loss: 1.714 -
# Epoch: 8/8 -  - Step: 3033/3696 Training Loss: 1.928 -
# Epoch: 8/8 -  - Step: 3095/3696 Training Loss: 1.451 -
# Epoch: 8/8 -  - Step: 3160/3696 Training Loss: 1.855 -
# Epoch: 8/8 -  - Step: 3222/3696 Training Loss: 1.987 -
# Epoch: 8/8 -  - Step: 3283/3696 Training Loss: 1.878 -
# Epoch: 8/8 -  - Step: 3343/3696 Training Loss: 1.743 -
# Epoch: 8/8 -  - Step: 3409/3696 Training Loss: 1.879 -
# Epoch: 8/8 -  - Step: 3475/3696 Training Loss: 1.889 -
# Epoch: 8/8 -  - Step: 3535/3696 Training Loss: 2.089 -
# Epoch: 8/8 -  - Step: 3591/3696 Training Loss: 2.094 -
# Epoch: 8/8 -  - Step: 3652/3696 Training Loss: 1.670 -
# Finished training
# Training started
# Epoch: 1/5 -  - Step: 63/3696 Training Loss: 2.615 -
# Epoch: 1/5 -  - Step: 123/3696 Training Loss: 2.357 -
# Epoch: 1/5 -  - Step: 191/3696 Training Loss: 2.421 -
# Epoch: 1/5 -  - Step: 254/3696 Training Loss: 2.387 -
# Epoch: 1/5 -  - Step: 315/3696 Training Loss: 2.399 -
# Epoch: 1/5 -  - Step: 376/3696 Training Loss: 2.492 -
# Epoch: 1/5 -  - Step: 434/3696 Training Loss: 2.317 -
# Epoch: 1/5 -  - Step: 496/3696 Training Loss: 2.325 -
# Epoch: 1/5 -  - Step: 557/3696 Training Loss: 2.537 -
# Epoch: 1/5 -  - Step: 614/3696 Training Loss: 2.409 -
# Epoch: 1/5 -  - Step: 673/3696 Training Loss: 2.292 -
# Epoch: 1/5 -  - Step: 733/3696 Training Loss: 2.341 -
# Epoch: 1/5 -  - Step: 789/3696 Training Loss: 2.210 -
# Epoch: 1/5 -  - Step: 850/3696 Training Loss: 2.028 -
# Epoch: 1/5 -  - Step: 914/3696 Training Loss: 2.477 -
# Epoch: 1/5 -  - Step: 978/3696 Training Loss: 2.230 -
# Epoch: 1/5 -  - Step: 1037/3696 Training Loss: 2.193 -
# Epoch: 1/5 -  - Step: 1098/3696 Training Loss: 2.290 -
# Epoch: 1/5 -  - Step: 1158/3696 Training Loss: 2.145 -
# Epoch: 1/5 -  - Step: 1224/3696 Training Loss: 2.606 -
# Epoch: 1/5 -  - Step: 1284/3696 Training Loss: 2.256 -
# Epoch: 1/5 -  - Step: 1349/3696 Training Loss: 2.516 -
# Epoch: 1/5 -  - Step: 1411/3696 Training Loss: 1.928 -
# Epoch: 1/5 -  - Step: 1479/3696 Training Loss: 1.979 -
# Epoch: 1/5 -  - Step: 1535/3696 Training Loss: 2.227 -
# Epoch: 1/5 -  - Step: 1601/3696 Training Loss: 2.483 -
# Epoch: 1/5 -  - Step: 1657/3696 Training Loss: 2.488 -
# Epoch: 1/5 -  - Step: 1713/3696 Training Loss: 2.170 -
# Epoch: 1/5 -  - Step: 1788/3696 Training Loss: 2.373 -
# Epoch: 1/5 - Training Loss: 2.3153936858177184 - Validation Loss: 2.5804124930325676 - Train Accuracy:  0.3160000145435333 - Validation Accuracy:  0.26643598079681396
# Epoch: 1/5 -  - Step: 1911/3696 Training Loss: 4.187 -
# Epoch: 1/5 -  - Step: 1969/3696 Training Loss: 1.807 -
# Epoch: 1/5 -  - Step: 2029/3696 Training Loss: 2.299 -
# Epoch: 1/5 -  - Step: 2086/3696 Training Loss: 2.626 -
# Epoch: 1/5 -  - Step: 2144/3696 Training Loss: 2.197 -
# Epoch: 1/5 -  - Step: 2211/3696 Training Loss: 2.267 -
# Epoch: 1/5 -  - Step: 2272/3696 Training Loss: 2.248 -
# Epoch: 1/5 -  - Step: 2339/3696 Training Loss: 2.335 -
# Epoch: 1/5 -  - Step: 2394/3696 Training Loss: 2.046 -
# Epoch: 1/5 -  - Step: 2459/3696 Training Loss: 1.907 -
# Epoch: 1/5 -  - Step: 2514/3696 Training Loss: 2.061 -
# Epoch: 1/5 -  - Step: 2573/3696 Training Loss: 1.961 -
# Epoch: 1/5 -  - Step: 2630/3696 Training Loss: 2.331 -
# Epoch: 1/5 -  - Step: 2693/3696 Training Loss: 2.216 -
# Epoch: 1/5 -  - Step: 2747/3696 Training Loss: 2.179 -
# Epoch: 1/5 -  - Step: 2807/3696 Training Loss: 2.184 -
# Epoch: 1/5 -  - Step: 2871/3696 Training Loss: 2.332 -
# Epoch: 1/5 -  - Step: 2937/3696 Training Loss: 1.834 -
# Epoch: 1/5 -  - Step: 2999/3696 Training Loss: 1.721 -
# Epoch: 1/5 -  - Step: 3061/3696 Training Loss: 1.901 -
# Epoch: 1/5 -  - Step: 3130/3696 Training Loss: 2.062 -
# Epoch: 1/5 -  - Step: 3195/3696 Training Loss: 2.109 -
# Epoch: 1/5 -  - Step: 3254/3696 Training Loss: 1.995 -
# Epoch: 1/5 -  - Step: 3317/3696 Training Loss: 2.403 -
# Epoch: 1/5 -  - Step: 3380/3696 Training Loss: 1.969 -
# Epoch: 1/5 -  - Step: 3452/3696 Training Loss: 1.965 -
# Epoch: 1/5 -  - Step: 3517/3696 Training Loss: 2.139 -
# Epoch: 1/5 -  - Step: 3575/3696 Training Loss: 2.088 -
# Epoch: 1/5 -  - Step: 3630/3696 Training Loss: 2.407 -
# Epoch: 2/5 - Training Loss: 2.1253484926223756 - Validation Loss: 2.6003784489879145 - Train Accuracy:  0.3880000114440918 - Validation Accuracy:  0.4013840854167938
# Epoch: 2/5 -  - Step: 71/3696 Training Loss: 3.515 -
# Epoch: 2/5 -  - Step: 128/3696 Training Loss: 1.776 -
# Epoch: 2/5 -  - Step: 186/3696 Training Loss: 1.833 -
# Epoch: 2/5 -  - Step: 248/3696 Training Loss: 2.214 -
# Epoch: 2/5 -  - Step: 312/3696 Training Loss: 2.257 -
# Epoch: 2/5 -  - Step: 374/3696 Training Loss: 1.930 -
# Epoch: 2/5 -  - Step: 429/3696 Training Loss: 1.974 -
# Epoch: 2/5 -  - Step: 491/3696 Training Loss: 2.137 -
# Epoch: 2/5 -  - Step: 556/3696 Training Loss: 2.118 -
# Epoch: 2/5 -  - Step: 623/3696 Training Loss: 2.256 -
# Epoch: 2/5 -  - Step: 683/3696 Training Loss: 1.732 -
# Epoch: 2/5 -  - Step: 744/3696 Training Loss: 2.062 -
# Epoch: 2/5 -  - Step: 804/3696 Training Loss: 1.787 -
# Epoch: 2/5 -  - Step: 860/3696 Training Loss: 2.017 -
# Epoch: 2/5 -  - Step: 923/3696 Training Loss: 2.163 -
# Epoch: 2/5 -  - Step: 989/3696 Training Loss: 2.056 -
# Epoch: 2/5 -  - Step: 1047/3696 Training Loss: 1.755 -
# Epoch: 2/5 -  - Step: 1102/3696 Training Loss: 1.861 -
# Epoch: 2/5 -  - Step: 1167/3696 Training Loss: 1.704 -
# Epoch: 2/5 -  - Step: 1227/3696 Training Loss: 2.046 -
# Epoch: 2/5 -  - Step: 1291/3696 Training Loss: 1.510 -
# Epoch: 2/5 -  - Step: 1357/3696 Training Loss: 1.824 -
# Epoch: 2/5 -  - Step: 1420/3696 Training Loss: 1.771 -
# Epoch: 2/5 -  - Step: 1485/3696 Training Loss: 1.844 -
# Epoch: 2/5 -  - Step: 1548/3696 Training Loss: 2.185 -
# Epoch: 2/5 -  - Step: 1606/3696 Training Loss: 2.098 -
# Epoch: 2/5 -  - Step: 1670/3696 Training Loss: 1.876 -
# Epoch: 2/5 -  - Step: 1728/3696 Training Loss: 1.737 -
# Epoch: 2/5 -  - Step: 1793/3696 Training Loss: 1.619 -
# Epoch: 2/5 - Training Loss: 1.9094856494267782 - Validation Loss: 2.7204878721063936 - Train Accuracy:  0.4320000112056732 - Validation Accuracy:  0.387543261051178
# Epoch: 2/5 -  - Step: 1912/3696 Training Loss: 3.259 -
# Epoch: 2/5 -  - Step: 1979/3696 Training Loss: 1.869 -
# Epoch: 2/5 -  - Step: 2047/3696 Training Loss: 1.729 -
# Epoch: 2/5 -  - Step: 2117/3696 Training Loss: 1.673 -
# Epoch: 2/5 -  - Step: 2176/3696 Training Loss: 1.668 -
# Epoch: 2/5 -  - Step: 2245/3696 Training Loss: 2.071 -
# Epoch: 2/5 -  - Step: 2301/3696 Training Loss: 1.541 -
# Epoch: 2/5 -  - Step: 2367/3696 Training Loss: 1.565 -
# Epoch: 2/5 -  - Step: 2430/3696 Training Loss: 1.517 -
# Epoch: 2/5 -  - Step: 2489/3696 Training Loss: 1.816 -
# Epoch: 2/5 -  - Step: 2556/3696 Training Loss: 1.785 -
# Epoch: 2/5 -  - Step: 2614/3696 Training Loss: 1.760 -
# Epoch: 2/5 -  - Step: 2678/3696 Training Loss: 2.073 -
# Epoch: 2/5 -  - Step: 2736/3696 Training Loss: 1.592 -
# Epoch: 2/5 -  - Step: 2799/3696 Training Loss: 1.587 -
# Epoch: 2/5 -  - Step: 2858/3696 Training Loss: 1.823 -
# Epoch: 2/5 -  - Step: 2914/3696 Training Loss: 1.799 -
# Epoch: 2/5 -  - Step: 2978/3696 Training Loss: 1.456 -
# Epoch: 2/5 -  - Step: 3039/3696 Training Loss: 1.663 -
# Epoch: 2/5 -  - Step: 3101/3696 Training Loss: 2.238 -
# Epoch: 2/5 -  - Step: 3160/3696 Training Loss: 1.596 -
# Epoch: 2/5 -  - Step: 3216/3696 Training Loss: 1.639 -
# Epoch: 2/5 -  - Step: 3273/3696 Training Loss: 1.896 -
# Epoch: 2/5 -  - Step: 3330/3696 Training Loss: 1.871 -
# Epoch: 2/5 -  - Step: 3396/3696 Training Loss: 1.727 -
# Epoch: 2/5 -  - Step: 3454/3696 Training Loss: 1.787 -
# Epoch: 2/5 -  - Step: 3513/3696 Training Loss: 1.243 -
# Epoch: 2/5 -  - Step: 3576/3696 Training Loss: 1.900 -
# Epoch: 2/5 -  - Step: 3639/3696 Training Loss: 1.814 -
# Epoch: 3/5 - Training Loss: 1.7319616882801057 - Validation Loss: 2.1885620728392916 - Train Accuracy:  0.48266667127609253 - Validation Accuracy:  0.39792388677597046
# Epoch: 3/5 -  - Step: 61/3696 Training Loss: 3.128 -
# Epoch: 3/5 -  - Step: 126/3696 Training Loss: 1.591 -
# Epoch: 3/5 -  - Step: 189/3696 Training Loss: 1.475 -
# Epoch: 3/5 -  - Step: 252/3696 Training Loss: 1.450 -
# Epoch: 3/5 -  - Step: 312/3696 Training Loss: 1.339 -
# Epoch: 3/5 -  - Step: 372/3696 Training Loss: 1.927 -
# Epoch: 3/5 -  - Step: 438/3696 Training Loss: 1.596 -
# Epoch: 3/5 -  - Step: 494/3696 Training Loss: 1.517 -
# Epoch: 3/5 -  - Step: 552/3696 Training Loss: 1.888 -
# Epoch: 3/5 -  - Step: 607/3696 Training Loss: 1.815 -
# Epoch: 3/5 -  - Step: 667/3696 Training Loss: 1.760 -
# Epoch: 3/5 -  - Step: 727/3696 Training Loss: 1.649 -
# Epoch: 3/5 -  - Step: 789/3696 Training Loss: 1.468 -
# Epoch: 3/5 -  - Step: 848/3696 Training Loss: 1.231 -
# Epoch: 3/5 -  - Step: 913/3696 Training Loss: 1.417 -
# Epoch: 3/5 -  - Step: 980/3696 Training Loss: 1.666 -
# Epoch: 3/5 -  - Step: 1042/3696 Training Loss: 1.561 -
# Epoch: 3/5 -  - Step: 1098/3696 Training Loss: 1.353 -
# Epoch: 3/5 -  - Step: 1160/3696 Training Loss: 1.287 -
# Epoch: 3/5 -  - Step: 1222/3696 Training Loss: 1.701 -
# Epoch: 3/5 -  - Step: 1295/3696 Training Loss: 1.528 -
# Epoch: 3/5 -  - Step: 1355/3696 Training Loss: 1.659 -
# Epoch: 3/5 -  - Step: 1416/3696 Training Loss: 1.674 -
# Epoch: 3/5 -  - Step: 1476/3696 Training Loss: 1.602 -
# Epoch: 3/5 -  - Step: 1532/3696 Training Loss: 1.461 -
# Epoch: 3/5 -  - Step: 1590/3696 Training Loss: 1.556 -
# Epoch: 3/5 -  - Step: 1663/3696 Training Loss: 1.641 -
# Epoch: 3/5 -  - Step: 1723/3696 Training Loss: 1.631 -
# Epoch: 3/5 -  - Step: 1786/3696 Training Loss: 1.577 -
# Epoch: 3/5 - Training Loss: 1.5637944212754566 - Validation Loss: 2.2546593730424926 - Train Accuracy:  0.5339999794960022 - Validation Accuracy:  0.3840830326080322
# Epoch: 3/5 -  - Step: 1919/3696 Training Loss: 2.675 -
# Epoch: 3/5 -  - Step: 1973/3696 Training Loss: 1.401 -
# Epoch: 3/5 -  - Step: 2035/3696 Training Loss: 1.358 -
# Epoch: 3/5 -  - Step: 2097/3696 Training Loss: 1.287 -
# Epoch: 3/5 -  - Step: 2158/3696 Training Loss: 1.610 -
# Epoch: 3/5 -  - Step: 2220/3696 Training Loss: 1.338 -
# Epoch: 3/5 -  - Step: 2286/3696 Training Loss: 1.433 -
# Epoch: 3/5 -  - Step: 2354/3696 Training Loss: 1.430 -
# Epoch: 3/5 -  - Step: 2416/3696 Training Loss: 1.567 -
# Epoch: 3/5 -  - Step: 2475/3696 Training Loss: 1.585 -
# Epoch: 3/5 -  - Step: 2534/3696 Training Loss: 1.304 -
# Epoch: 3/5 -  - Step: 2595/3696 Training Loss: 1.065 -
# Epoch: 3/5 -  - Step: 2657/3696 Training Loss: 1.521 -
# Epoch: 3/5 -  - Step: 2714/3696 Training Loss: 1.767 -
# Epoch: 3/5 -  - Step: 2776/3696 Training Loss: 1.645 -
# Epoch: 3/5 -  - Step: 2838/3696 Training Loss: 1.834 -
# Epoch: 3/5 -  - Step: 2902/3696 Training Loss: 1.505 -
# Epoch: 3/5 -  - Step: 2959/3696 Training Loss: 1.407 -
# Epoch: 3/5 -  - Step: 3025/3696 Training Loss: 1.400 -
# Epoch: 3/5 -  - Step: 3085/3696 Training Loss: 1.628 -
# Epoch: 3/5 -  - Step: 3148/3696 Training Loss: 2.051 -
# Epoch: 3/5 -  - Step: 3207/3696 Training Loss: 1.509 -
# Epoch: 3/5 -  - Step: 3266/3696 Training Loss: 1.535 -
# Epoch: 3/5 -  - Step: 3337/3696 Training Loss: 1.685 -
# Epoch: 3/5 -  - Step: 3399/3696 Training Loss: 1.424 -
# Epoch: 3/5 -  - Step: 3459/3696 Training Loss: 1.950 -
# Epoch: 3/5 -  - Step: 3522/3696 Training Loss: 1.514 -
# Epoch: 3/5 -  - Step: 3578/3696 Training Loss: 1.930 -
# Epoch: 3/5 -  - Step: 3639/3696 Training Loss: 1.596 -
# Epoch: 4/5 - Training Loss: 1.536715749025345 - Validation Loss: 2.3206976404652053 - Train Accuracy:  0.5540000200271606 - Validation Accuracy:  0.5138408541679382
# Epoch: 4/5 -  - Step: 76/3696 Training Loss: 2.891 -
# Epoch: 4/5 -  - Step: 141/3696 Training Loss: 1.116 -
# Epoch: 4/5 -  - Step: 201/3696 Training Loss: 0.905 -
# Epoch: 4/5 -  - Step: 257/3696 Training Loss: 1.176 -
# Epoch: 4/5 -  - Step: 312/3696 Training Loss: 1.311 -
# Epoch: 4/5 -  - Step: 372/3696 Training Loss: 1.661 -
# Epoch: 4/5 -  - Step: 436/3696 Training Loss: 1.119 -
# Epoch: 4/5 -  - Step: 492/3696 Training Loss: 1.497 -
# Epoch: 4/5 -  - Step: 557/3696 Training Loss: 1.317 -
# Epoch: 4/5 -  - Step: 620/3696 Training Loss: 1.294 -
# Epoch: 4/5 -  - Step: 680/3696 Training Loss: 1.196 -
# Epoch: 4/5 -  - Step: 744/3696 Training Loss: 1.397 -
# Epoch: 4/5 -  - Step: 808/3696 Training Loss: 1.439 -
# Epoch: 4/5 -  - Step: 866/3696 Training Loss: 1.400 -
# Epoch: 4/5 -  - Step: 924/3696 Training Loss: 1.728 -
# Epoch: 4/5 -  - Step: 978/3696 Training Loss: 1.406 -
# Epoch: 4/5 -  - Step: 1047/3696 Training Loss: 1.215 -
# Epoch: 4/5 -  - Step: 1113/3696 Training Loss: 1.094 -
# Epoch: 4/5 -  - Step: 1177/3696 Training Loss: 1.510 -
# Epoch: 4/5 -  - Step: 1239/3696 Training Loss: 1.204 -
# Epoch: 4/5 -  - Step: 1296/3696 Training Loss: 1.862 -
# Epoch: 4/5 -  - Step: 1355/3696 Training Loss: 1.396 -
# Epoch: 4/5 -  - Step: 1415/3696 Training Loss: 1.693 -
# Epoch: 4/5 -  - Step: 1482/3696 Training Loss: 1.382 -
# Epoch: 4/5 -  - Step: 1539/3696 Training Loss: 1.651 -
# Epoch: 4/5 -  - Step: 1600/3696 Training Loss: 1.516 -
# Epoch: 4/5 -  - Step: 1658/3696 Training Loss: 1.145 -
# Epoch: 4/5 -  - Step: 1729/3696 Training Loss: 1.384 -
# Epoch: 4/5 -  - Step: 1789/3696 Training Loss: 1.211 -
# Epoch: 4/5 - Training Loss: 1.3528702487945556 - Validation Loss: 3.5173702294645013 - Train Accuracy:  0.593999981880188 - Validation Accuracy:  0.4238754212856293
# Epoch: 4/5 -  - Step: 1914/3696 Training Loss: 2.202 -
# Epoch: 4/5 -  - Step: 1979/3696 Training Loss: 1.157 -
# Epoch: 4/5 -  - Step: 2045/3696 Training Loss: 1.403 -
# Epoch: 4/5 -  - Step: 2108/3696 Training Loss: 1.162 -
# Epoch: 4/5 -  - Step: 2173/3696 Training Loss: 1.329 -
# Epoch: 4/5 -  - Step: 2235/3696 Training Loss: 1.289 -
# Epoch: 4/5 -  - Step: 2296/3696 Training Loss: 1.451 -
# Epoch: 4/5 -  - Step: 2356/3696 Training Loss: 1.461 -
# Epoch: 4/5 -  - Step: 2410/3696 Training Loss: 1.073 -
# Epoch: 4/5 -  - Step: 2473/3696 Training Loss: 1.458 -
# Epoch: 4/5 -  - Step: 2531/3696 Training Loss: 1.140 -
# Epoch: 4/5 -  - Step: 2591/3696 Training Loss: 1.351 -
# Epoch: 4/5 -  - Step: 2655/3696 Training Loss: 1.322 -
# Epoch: 4/5 -  - Step: 2716/3696 Training Loss: 1.566 -
# Epoch: 4/5 -  - Step: 2776/3696 Training Loss: 0.975 -
# Epoch: 4/5 -  - Step: 2840/3696 Training Loss: 1.488 -
# Epoch: 4/5 -  - Step: 2903/3696 Training Loss: 1.662 -
# Epoch: 4/5 -  - Step: 2962/3696 Training Loss: 1.345 -
# Epoch: 4/5 -  - Step: 3021/3696 Training Loss: 1.303 -
# Epoch: 4/5 -  - Step: 3081/3696 Training Loss: 1.084 -
# Epoch: 4/5 -  - Step: 3144/3696 Training Loss: 1.156 -
# Epoch: 4/5 -  - Step: 3202/3696 Training Loss: 1.041 -
# Epoch: 4/5 -  - Step: 3268/3696 Training Loss: 1.424 -
# Epoch: 4/5 -  - Step: 3334/3696 Training Loss: 1.068 -
# Epoch: 4/5 -  - Step: 3397/3696 Training Loss: 0.991 -
# Epoch: 4/5 -  - Step: 3461/3696 Training Loss: 1.355 -
# Epoch: 4/5 -  - Step: 3524/3696 Training Loss: 1.059 -
# Epoch: 4/5 -  - Step: 3582/3696 Training Loss: 1.654 -
# Epoch: 4/5 -  - Step: 3645/3696 Training Loss: 0.995 -
# Epoch: 5/5 - Training Loss: 1.27286723502477 - Validation Loss: 3.2707982831038405 - Train Accuracy:  0.6213333606719971 - Validation Accuracy:  0.46020761132240295
# Epoch: 5/5 -  - Step: 73/3696 Training Loss: 2.476 -
# Epoch: 5/5 -  - Step: 133/3696 Training Loss: 1.319 -
# Epoch: 5/5 -  - Step: 204/3696 Training Loss: 1.345 -
# Epoch: 5/5 -  - Step: 274/3696 Training Loss: 1.347 -
# Epoch: 5/5 -  - Step: 340/3696 Training Loss: 0.859 -
# Epoch: 5/5 -  - Step: 404/3696 Training Loss: 1.521 -
# Epoch: 5/5 -  - Step: 467/3696 Training Loss: 1.062 -
# Epoch: 5/5 -  - Step: 526/3696 Training Loss: 1.154 -
# Epoch: 5/5 -  - Step: 589/3696 Training Loss: 1.564 -
# Epoch: 5/5 -  - Step: 651/3696 Training Loss: 1.310 -
# Epoch: 5/5 -  - Step: 708/3696 Training Loss: 1.280 -
# Epoch: 5/5 -  - Step: 773/3696 Training Loss: 0.939 -
# Epoch: 5/5 -  - Step: 838/3696 Training Loss: 1.199 -
# Epoch: 5/5 -  - Step: 900/3696 Training Loss: 1.380 -
# Epoch: 5/5 -  - Step: 961/3696 Training Loss: 1.216 -
# Epoch: 5/5 -  - Step: 1020/3696 Training Loss: 1.129 -
# Epoch: 5/5 -  - Step: 1080/3696 Training Loss: 1.313 -
# Epoch: 5/5 -  - Step: 1140/3696 Training Loss: 0.988 -
# Epoch: 5/5 -  - Step: 1198/3696 Training Loss: 0.907 -
# Epoch: 5/5 -  - Step: 1267/3696 Training Loss: 1.244 -
# Epoch: 5/5 -  - Step: 1328/3696 Training Loss: 1.330 -
# Epoch: 5/5 -  - Step: 1387/3696 Training Loss: 1.018 -
# Epoch: 5/5 -  - Step: 1448/3696 Training Loss: 1.291 -
# Epoch: 5/5 -  - Step: 1510/3696 Training Loss: 1.318 -
# Epoch: 5/5 -  - Step: 1572/3696 Training Loss: 1.035 -
# Epoch: 5/5 -  - Step: 1635/3696 Training Loss: 0.895 -
# Epoch: 5/5 -  - Step: 1691/3696 Training Loss: 0.854 -
# Epoch: 5/5 -  - Step: 1745/3696 Training Loss: 1.434 -
# Epoch: 5/5 -  - Step: 1803/3696 Training Loss: 0.987 -
# Epoch: 5/5 - Training Loss: 1.1997970662117003 - Validation Loss: 3.311167436178168 - Train Accuracy:  0.621999979019165 - Validation Accuracy:  0.4550172984600067
# Epoch: 5/5 -  - Step: 1924/3696 Training Loss: 2.414 -
# Epoch: 5/5 -  - Step: 1987/3696 Training Loss: 1.275 -
# Epoch: 5/5 -  - Step: 2050/3696 Training Loss: 1.085 -
# Epoch: 5/5 -  - Step: 2111/3696 Training Loss: 0.883 -
# Epoch: 5/5 -  - Step: 2172/3696 Training Loss: 1.310 -
# Epoch: 5/5 -  - Step: 2236/3696 Training Loss: 1.181 -
# Epoch: 5/5 -  - Step: 2300/3696 Training Loss: 0.920 -
# Epoch: 5/5 -  - Step: 2359/3696 Training Loss: 1.267 -
# Epoch: 5/5 -  - Step: 2429/3696 Training Loss: 1.560 -
# Epoch: 5/5 -  - Step: 2494/3696 Training Loss: 1.322 -
# Epoch: 5/5 -  - Step: 2549/3696 Training Loss: 1.030 -
# Epoch: 5/5 -  - Step: 2609/3696 Training Loss: 0.930 -
# Epoch: 5/5 -  - Step: 2668/3696 Training Loss: 0.754 -
# Epoch: 5/5 -  - Step: 2724/3696 Training Loss: 0.903 -
# Epoch: 5/5 -  - Step: 2784/3696 Training Loss: 1.345 -
# Epoch: 5/5 -  - Step: 2847/3696 Training Loss: 1.531 -
# Epoch: 5/5 -  - Step: 2908/3696 Training Loss: 0.704 -
# Epoch: 5/5 -  - Step: 2964/3696 Training Loss: 1.358 -
# Epoch: 5/5 -  - Step: 3026/3696 Training Loss: 1.127 -
# Epoch: 5/5 -  - Step: 3086/3696 Training Loss: 0.948 -
# Epoch: 5/5 -  - Step: 3148/3696 Training Loss: 1.271 -
# Epoch: 5/5 -  - Step: 3209/3696 Training Loss: 0.772 -
# Epoch: 5/5 -  - Step: 3272/3696 Training Loss: 1.061 -
# Epoch: 5/5 -  - Step: 3335/3696 Training Loss: 0.751 -
# Epoch: 5/5 -  - Step: 3401/3696 Training Loss: 1.331 -
# Epoch: 5/5 -  - Step: 3462/3696 Training Loss: 0.969 -
# Epoch: 5/5 -  - Step: 3525/3696 Training Loss: 0.721 -
# Epoch: 5/5 -  - Step: 3588/3696 Training Loss: 1.493 -
# Epoch: 5/5 -  - Step: 3651/3696 Training Loss: 1.048 -
# Finished training
# Training started
# Epoch: 1/7 -  - Step: 64/3696 Training Loss: 0.744 -
# Epoch: 1/7 -  - Step: 123/3696 Training Loss: 1.258 -
# Epoch: 1/7 -  - Step: 187/3696 Training Loss: 1.121 -
# Epoch: 1/7 -  - Step: 253/3696 Training Loss: 0.953 -
# Epoch: 1/7 -  - Step: 311/3696 Training Loss: 0.674 -
# Epoch: 1/7 -  - Step: 373/3696 Training Loss: 0.629 -
# Epoch: 1/7 -  - Step: 437/3696 Training Loss: 1.385 -
# Epoch: 1/7 -  - Step: 495/3696 Training Loss: 1.302 -
# Epoch: 1/7 -  - Step: 556/3696 Training Loss: 1.162 -
# Epoch: 1/7 -  - Step: 611/3696 Training Loss: 0.987 -
# Epoch: 1/7 -  - Step: 665/3696 Training Loss: 0.949 -
# Epoch: 1/7 -  - Step: 727/3696 Training Loss: 0.757 -
# Epoch: 1/7 -  - Step: 792/3696 Training Loss: 0.794 -
# ...
# Epoch: 3/7 -  - Step: 1921/3696 Training Loss: 1.168 -
# Epoch: 3/7 -  - Step: 1979/3696 Training Loss: 0.718 -
# Epoch: 3/7 -  - Step: 2043/3696 Training Loss: 0.607 -
# Epoch: 3/7 -  - Step: 2100/3696 Training Loss: 1.102 -
# Epoch: 3/7 -  - Step: 2163/3696 Training Loss: 0.732 -
# Epoch: 3/7 -  - Step: 2224/3696 Training Loss: 0.811 -
# Epoch: 3/7 -  - Step: 2288/3696 Training Loss: 0.660 -
# Epoch: 3/7 -  - Step: 2348/3696 Training Loss: 0.375 -
# Epoch: 3/7 -  - Step: 2407/3696 Training Loss: 0.631 -
# Epoch: 3/7 -  - Step: 2472/3696 Training Loss: 0.601 -
# Epoch: 3/7 -  - Step: 2533/3696 Training Loss: 0.829 -
# Epoch: 3/7 -  - Step: 2593/3696 Training Loss: 0.930 -
# Epoch: 3/7 -  - Step: 2654/3696 Training Loss: 0.676 -
# Epoch: 3/7 -  - Step: 2713/3696 Training Loss: 1.025 -
# Epoch: 3/7 -  - Step: 2772/3696 Training Loss: 0.812 -
# Epoch: 3/7 -  - Step: 2831/3696 Training Loss: 0.440 -
# Epoch: 3/7 -  - Step: 2892/3696 Training Loss: 0.694 -
# Epoch: 3/7 -  - Step: 2959/3696 Training Loss: 0.704 -
# Epoch: 3/7 -  - Step: 3023/3696 Training Loss: 0.465 -
# Epoch: 3/7 -  - Step: 3086/3696 Training Loss: 0.557 -
# Epoch: 3/7 -  - Step: 3142/3696 Training Loss: 0.582 -
# Epoch: 3/7 -  - Step: 3198/3696 Training Loss: 0.677 -
# Epoch: 3/7 -  - Step: 3270/3696 Training Loss: 0.844 -
# Epoch: 3/7 -  - Step: 3327/3696 Training Loss: 0.323 -
# Epoch: 3/7 -  - Step: 3393/3696 Training Loss: 0.764 -
# Epoch: 3/7 -  - Step: 3456/3696 Training Loss: 0.977 -
# Epoch: 3/7 -  - Step: 3519/3696 Training Loss: 0.729 -
# Epoch: 3/7 -  - Step: 3580/3696 Training Loss: 0.668 -
# Epoch: 3/7 -  - Step: 3645/3696 Training Loss: 1.035 -
# Epoch: 4/7 - Training Loss: 0.7080605487028758 - Validation Loss: 3.1761580328730976 - Train Accuracy:  0.75 - Validation Accuracy:  0.5467128157615662
# Epoch: 4/7 -  - Step: 65/3696 Training Loss: 1.202 -
# Epoch: 4/7 -  - Step: 133/3696 Training Loss: 0.722 -
# Epoch: 4/7 -  - Step: 194/3696 Training Loss: 0.628 -
# Epoch: 4/7 -  - Step: 256/3696 Training Loss: 0.569 -
# Epoch: 4/7 -  - Step: 316/3696 Training Loss: 0.801 -
# Epoch: 4/7 -  - Step: 379/3696 Training Loss: 0.774 -
# Epoch: 4/7 -  - Step: 439/3696 Training Loss: 0.562 -
# Epoch: 4/7 -  - Step: 506/3696 Training Loss: 0.549 -
# Epoch: 4/7 -  - Step: 565/3696 Training Loss: 0.870 -
# Epoch: 4/7 -  - Step: 630/3696 Training Loss: 0.811 -
# Epoch: 4/7 -  - Step: 689/3696 Training Loss: 0.641 -
# Epoch: 4/7 -  - Step: 752/3696 Training Loss: 0.657 -
# Epoch: 4/7 -  - Step: 815/3696 Training Loss: 0.770 -
# Epoch: 4/7 -  - Step: 873/3696 Training Loss: 0.597 -
# Epoch: 4/7 -  - Step: 933/3696 Training Loss: 0.712 -
# Epoch: 4/7 -  - Step: 989/3696 Training Loss: 0.566 -
# Epoch: 4/7 -  - Step: 1048/3696 Training Loss: 0.810 -
# Epoch: 4/7 -  - Step: 1114/3696 Training Loss: 0.673 -
# Epoch: 4/7 -  - Step: 1171/3696 Training Loss: 0.774 -
# Epoch: 4/7 -  - Step: 1226/3696 Training Loss: 1.008 -
# Epoch: 4/7 -  - Step: 1287/3696 Training Loss: 0.957 -
# Epoch: 4/7 -  - Step: 1347/3696 Training Loss: 0.670 -
# Epoch: 4/7 -  - Step: 1408/3696 Training Loss: 0.701 -
# Epoch: 4/7 -  - Step: 1463/3696 Training Loss: 0.722 -
# Epoch: 4/7 -  - Step: 1523/3696 Training Loss: 0.861 -
# Epoch: 4/7 -  - Step: 1583/3696 Training Loss: 0.781 -
# Epoch: 4/7 -  - Step: 1653/3696 Training Loss: 0.626 -
# Epoch: 4/7 -  - Step: 1712/3696 Training Loss: 0.613 -
# Epoch: 4/7 -  - Step: 1772/3696 Training Loss: 0.932 -
# Epoch: 4/7 - Training Loss: 0.7156742517153422 - Validation Loss: 3.224344827569892 - Train Accuracy:  0.7433333396911621 - Validation Accuracy:  0.5467128157615662
# Epoch: 4/7 -  - Step: 1890/3696 Training Loss: 1.076 -
# Epoch: 4/7 -  - Step: 1953/3696 Training Loss: 0.619 -
# Epoch: 4/7 -  - Step: 2015/3696 Training Loss: 0.770 -
# Epoch: 4/7 -  - Step: 2077/3696 Training Loss: 0.508 -
# Epoch: 4/7 -  - Step: 2135/3696 Training Loss: 0.531 -
# Epoch: 4/7 -  - Step: 2195/3696 Training Loss: 0.526 -
# Epoch: 4/7 -  - Step: 2256/3696 Training Loss: 0.552 -
# Epoch: 4/7 -  - Step: 2319/3696 Training Loss: 0.478 -
# Epoch: 4/7 -  - Step: 2380/3696 Training Loss: 0.949 -
# Epoch: 4/7 -  - Step: 2451/3696 Training Loss: 0.952 -
# Epoch: 4/7 -  - Step: 2513/3696 Training Loss: 0.662 -
# Epoch: 4/7 -  - Step: 2577/3696 Training Loss: 0.633 -
# Epoch: 4/7 -  - Step: 2641/3696 Training Loss: 1.035 -
# Epoch: 4/7 -  - Step: 2699/3696 Training Loss: 0.762 -
# Epoch: 4/7 -  - Step: 2764/3696 Training Loss: 0.668 -
# Epoch: 4/7 -  - Step: 2827/3696 Training Loss: 0.837 -
# Epoch: 4/7 -  - Step: 2884/3696 Training Loss: 0.845 -
# Epoch: 4/7 -  - Step: 2951/3696 Training Loss: 1.080 -
# Epoch: 4/7 -  - Step: 3015/3696 Training Loss: 0.814 -
# Epoch: 4/7 -  - Step: 3078/3696 Training Loss: 0.638 -
# Epoch: 4/7 -  - Step: 3139/3696 Training Loss: 0.887 -
# Epoch: 4/7 -  - Step: 3202/3696 Training Loss: 0.907 -
# Epoch: 4/7 -  - Step: 3264/3696 Training Loss: 0.724 -
# Epoch: 4/7 -  - Step: 3323/3696 Training Loss: 0.656 -
# Epoch: 4/7 -  - Step: 3387/3696 Training Loss: 0.487 -
# Epoch: 4/7 -  - Step: 3449/3696 Training Loss: 0.616 -
# Epoch: 4/7 -  - Step: 3516/3696 Training Loss: 0.862 -
# Epoch: 4/7 -  - Step: 3574/3696 Training Loss: 0.866 -
# Epoch: 4/7 -  - Step: 3643/3696 Training Loss: 0.649 -
# Epoch: 5/7 - Training Loss: 0.7210294188658396 - Validation Loss: 3.260156229215716 - Train Accuracy:  0.737333357334137 - Validation Accuracy:  0.5501729846000671
# Epoch: 5/7 -  - Step: 78/3696 Training Loss: 1.435 -
# Epoch: 5/7 -  - Step: 137/3696 Training Loss: 0.950 -
# Epoch: 5/7 -  - Step: 207/3696 Training Loss: 0.584 -
# Epoch: 5/7 -  - Step: 271/3696 Training Loss: 0.464 -
# Epoch: 5/7 -  - Step: 332/3696 Training Loss: 0.521 -
# Epoch: 5/7 -  - Step: 404/3696 Training Loss: 0.603 -
# Epoch: 5/7 -  - Step: 458/3696 Training Loss: 0.741 -
# Epoch: 5/7 -  - Step: 518/3696 Training Loss: 0.699 -
# Epoch: 5/7 -  - Step: 577/3696 Training Loss: 0.826 -
# Epoch: 5/7 -  - Step: 637/3696 Training Loss: 0.600 -
# Epoch: 5/7 -  - Step: 691/3696 Training Loss: 0.598 -
# Epoch: 5/7 -  - Step: 757/3696 Training Loss: 0.645 -
# Epoch: 5/7 -  - Step: 819/3696 Training Loss: 0.896 -
# Epoch: 5/7 -  - Step: 879/3696 Training Loss: 0.708 -
# Epoch: 5/7 -  - Step: 944/3696 Training Loss: 0.941 -
# Epoch: 5/7 -  - Step: 1008/3696 Training Loss: 0.715 -
# Epoch: 5/7 -  - Step: 1066/3696 Training Loss: 0.604 -
# Epoch: 5/7 -  - Step: 1126/3696 Training Loss: 0.670 -
# Epoch: 5/7 -  - Step: 1180/3696 Training Loss: 0.395 -
# Epoch: 5/7 -  - Step: 1241/3696 Training Loss: 0.462 -
# Epoch: 5/7 -  - Step: 1301/3696 Training Loss: 0.689 -
# Epoch: 5/7 -  - Step: 1372/3696 Training Loss: 0.813 -
# Epoch: 5/7 -  - Step: 1429/3696 Training Loss: 0.619 -
# Epoch: 5/7 -  - Step: 1485/3696 Training Loss: 0.928 -
# Epoch: 5/7 -  - Step: 1545/3696 Training Loss: 0.664 -
# Epoch: 5/7 -  - Step: 1611/3696 Training Loss: 0.626 -
# Epoch: 5/7 -  - Step: 1682/3696 Training Loss: 0.788 -
# Epoch: 5/7 -  - Step: 1742/3696 Training Loss: 0.735 -
# Epoch: 5/7 -  - Step: 1803/3696 Training Loss: 0.498 -
# Epoch: 5/7 - Training Loss: 0.68385710867246 - Validation Loss: 3.2915677390090323 - Train Accuracy:  0.7580000162124634 - Validation Accuracy:  0.5467128157615662
# Epoch: 5/7 -  - Step: 1926/3696 Training Loss: 1.163 -
# Epoch: 5/7 -  - Step: 1991/3696 Training Loss: 0.483 -
# Epoch: 5/7 -  - Step: 2050/3696 Training Loss: 0.597 -
# Epoch: 5/7 -  - Step: 2116/3696 Training Loss: 0.539 -
# Epoch: 5/7 -  - Step: 2174/3696 Training Loss: 0.398 -
# Epoch: 5/7 -  - Step: 2232/3696 Training Loss: 0.746 -
# Epoch: 5/7 -  - Step: 2291/3696 Training Loss: 0.466 -
# Epoch: 5/7 -  - Step: 2354/3696 Training Loss: 0.770 -
# Epoch: 5/7 -  - Step: 2410/3696 Training Loss: 0.569 -
# Epoch: 5/7 -  - Step: 2476/3696 Training Loss: 0.885 -
# Epoch: 5/7 -  - Step: 2543/3696 Training Loss: 0.556 -
# Epoch: 5/7 -  - Step: 2604/3696 Training Loss: 0.411 -
# Epoch: 5/7 -  - Step: 2663/3696 Training Loss: 0.727 -
# Epoch: 5/7 -  - Step: 2724/3696 Training Loss: 0.795 -
# Epoch: 5/7 -  - Step: 2790/3696 Training Loss: 0.660 -
# Epoch: 5/7 -  - Step: 2852/3696 Training Loss: 0.597 -
# Epoch: 5/7 -  - Step: 2916/3696 Training Loss: 0.638 -
# Epoch: 5/7 -  - Step: 2979/3696 Training Loss: 0.708 -
# Epoch: 5/7 -  - Step: 3039/3696 Training Loss: 0.796 -
# Epoch: 5/7 -  - Step: 3103/3696 Training Loss: 0.754 -
# Epoch: 5/7 -  - Step: 3160/3696 Training Loss: 0.603 -
# Epoch: 5/7 -  - Step: 3221/3696 Training Loss: 0.449 -
# Epoch: 5/7 -  - Step: 3285/3696 Training Loss: 0.765 -
# Epoch: 5/7 -  - Step: 3343/3696 Training Loss: 0.786 -
# Epoch: 5/7 -  - Step: 3409/3696 Training Loss: 0.698 -
# Epoch: 5/7 -  - Step: 3466/3696 Training Loss: 0.612 -
# Epoch: 5/7 -  - Step: 3526/3696 Training Loss: 0.469 -
# Epoch: 5/7 -  - Step: 3587/3696 Training Loss: 0.648 -
# Epoch: 5/7 -  - Step: 3649/3696 Training Loss: 0.558 -
# Epoch: 6/7 - Training Loss: 0.6347358371416728 - Validation Loss: 3.3943189740902824 - Train Accuracy:  0.7699999809265137 - Validation Accuracy:  0.5363321900367737
# Epoch: 6/7 -  - Step: 79/3696 Training Loss: 1.322 -
# Epoch: 6/7 -  - Step: 136/3696 Training Loss: 0.678 -
# Epoch: 6/7 -  - Step: 198/3696 Training Loss: 0.801 -
# Epoch: 6/7 -  - Step: 260/3696 Training Loss: 0.400 -
# Epoch: 6/7 -  - Step: 328/3696 Training Loss: 0.632 -
# Epoch: 6/7 -  - Step: 387/3696 Training Loss: 0.676 -
# Epoch: 6/7 -  - Step: 453/3696 Training Loss: 0.839 -
# Epoch: 6/7 -  - Step: 515/3696 Training Loss: 0.901 -
# Epoch: 6/7 -  - Step: 578/3696 Training Loss: 0.751 -
# Epoch: 6/7 -  - Step: 640/3696 Training Loss: 0.589 -
# Epoch: 6/7 -  - Step: 704/3696 Training Loss: 0.982 -
# Epoch: 6/7 -  - Step: 767/3696 Training Loss: 0.515 -
# Epoch: 6/7 -  - Step: 830/3696 Training Loss: 0.586 -
# Epoch: 6/7 -  - Step: 890/3696 Training Loss: 0.872 -
# Epoch: 6/7 -  - Step: 948/3696 Training Loss: 0.779 -
# Epoch: 6/7 -  - Step: 1005/3696 Training Loss: 0.970 -
# Epoch: 6/7 -  - Step: 1068/3696 Training Loss: 0.655 -
# Epoch: 6/7 -  - Step: 1126/3696 Training Loss: 0.744 -
# Epoch: 6/7 -  - Step: 1187/3696 Training Loss: 0.672 -
# Epoch: 6/7 -  - Step: 1246/3696 Training Loss: 0.770 -
# Epoch: 6/7 -  - Step: 1308/3696 Training Loss: 0.783 -
# Epoch: 6/7 -  - Step: 1370/3696 Training Loss: 0.740 -
# Epoch: 6/7 -  - Step: 1434/3696 Training Loss: 0.608 -
# Epoch: 6/7 -  - Step: 1492/3696 Training Loss: 0.523 -
# Epoch: 6/7 -  - Step: 1551/3696 Training Loss: 0.938 -
# Epoch: 6/7 -  - Step: 1610/3696 Training Loss: 0.477 -
# Epoch: 6/7 -  - Step: 1671/3696 Training Loss: 0.708 -
# Epoch: 6/7 -  - Step: 1729/3696 Training Loss: 0.765 -
# Epoch: 6/7 -  - Step: 1792/3696 Training Loss: 0.959 -
# Epoch: 6/7 - Training Loss: 0.7209169075489045 - Validation Loss: 3.485027513289534 - Train Accuracy:  0.7353333234786987 - Validation Accuracy:  0.5328719615936279
# Epoch: 6/7 -  - Step: 1921/3696 Training Loss: 1.536 -
# Epoch: 6/7 -  - Step: 1983/3696 Training Loss: 0.510 -
# Epoch: 6/7 -  - Step: 2050/3696 Training Loss: 0.496 -
# Epoch: 6/7 -  - Step: 2116/3696 Training Loss: 0.675 -
# Epoch: 6/7 -  - Step: 2171/3696 Training Loss: 0.814 -
# Epoch: 6/7 -  - Step: 2229/3696 Training Loss: 0.575 -
# Epoch: 6/7 -  - Step: 2289/3696 Training Loss: 0.401 -
# Epoch: 6/7 -  - Step: 2343/3696 Training Loss: 0.477 -
# Epoch: 6/7 -  - Step: 2401/3696 Training Loss: 0.694 -
# Epoch: 6/7 -  - Step: 2458/3696 Training Loss: 0.846 -
# Epoch: 6/7 -  - Step: 2531/3696 Training Loss: 0.711 -
# Epoch: 6/7 -  - Step: 2597/3696 Training Loss: 0.720 -
# Epoch: 6/7 -  - Step: 2659/3696 Training Loss: 0.748 -
# Epoch: 6/7 -  - Step: 2717/3696 Training Loss: 0.404 -
# Epoch: 6/7 -  - Step: 2780/3696 Training Loss: 0.827 -
# Epoch: 6/7 -  - Step: 2839/3696 Training Loss: 0.928 -
# Epoch: 6/7 -  - Step: 2907/3696 Training Loss: 0.386 -
# Epoch: 6/7 -  - Step: 2973/3696 Training Loss: 0.709 -
# Epoch: 6/7 -  - Step: 3032/3696 Training Loss: 0.937 -
# Epoch: 6/7 -  - Step: 3099/3696 Training Loss: 0.747 -
# Epoch: 6/7 -  - Step: 3166/3696 Training Loss: 0.484 -
# Epoch: 6/7 -  - Step: 3227/3696 Training Loss: 0.495 -
# Epoch: 6/7 -  - Step: 3286/3696 Training Loss: 0.887 -
# Epoch: 6/7 -  - Step: 3342/3696 Training Loss: 0.524 -
# Epoch: 6/7 -  - Step: 3408/3696 Training Loss: 1.100 -
# Epoch: 6/7 -  - Step: 3470/3696 Training Loss: 0.690 -
# Epoch: 6/7 -  - Step: 3533/3696 Training Loss: 0.739 -
# Epoch: 6/7 -  - Step: 3589/3696 Training Loss: 0.832 -
# Epoch: 6/7 -  - Step: 3651/3696 Training Loss: 0.552 -
# Epoch: 7/7 - Training Loss: 0.6693649905522664 - Validation Loss: 3.4462717196365955 - Train Accuracy:  0.7599999904632568 - Validation Accuracy:  0.5467128157615662
# Epoch: 7/7 -  - Step: 74/3696 Training Loss: 1.114 -
# Epoch: 7/7 -  - Step: 145/3696 Training Loss: 0.495 -
# Epoch: 7/7 -  - Step: 205/3696 Training Loss: 0.590 -
# Epoch: 7/7 -  - Step: 266/3696 Training Loss: 0.761 -
# Epoch: 7/7 -  - Step: 327/3696 Training Loss: 0.523 -
# Epoch: 7/7 -  - Step: 389/3696 Training Loss: 0.537 -
# Epoch: 7/7 -  - Step: 450/3696 Training Loss: 0.570 -
# Epoch: 7/7 -  - Step: 511/3696 Training Loss: 0.948 -
# Epoch: 7/7 -  - Step: 580/3696 Training Loss: 0.728 -
# Epoch: 7/7 -  - Step: 641/3696 Training Loss: 0.620 -
# Epoch: 7/7 -  - Step: 701/3696 Training Loss: 0.859 -
# Epoch: 7/7 -  - Step: 761/3696 Training Loss: 0.814 -
# Epoch: 7/7 -  - Step: 818/3696 Training Loss: 0.626 -
# Epoch: 7/7 -  - Step: 876/3696 Training Loss: 0.751 -
# Epoch: 7/7 -  - Step: 938/3696 Training Loss: 0.913 -
# Epoch: 7/7 -  - Step: 999/3696 Training Loss: 0.626 -
# Epoch: 7/7 -  - Step: 1060/3696 Training Loss: 0.749 -
# Epoch: 7/7 -  - Step: 1116/3696 Training Loss: 0.678 -
# Epoch: 7/7 -  - Step: 1180/3696 Training Loss: 0.553 -
# Epoch: 7/7 -  - Step: 1237/3696 Training Loss: 0.679 -
# Epoch: 7/7 -  - Step: 1298/3696 Training Loss: 0.665 -
# Epoch: 7/7 -  - Step: 1362/3696 Training Loss: 0.354 -
# Epoch: 7/7 -  - Step: 1416/3696 Training Loss: 0.399 -
# Epoch: 7/7 -  - Step: 1472/3696 Training Loss: 0.634 -
# Epoch: 7/7 -  - Step: 1532/3696 Training Loss: 0.490 -
# Epoch: 7/7 -  - Step: 1594/3696 Training Loss: 1.026 -
# Epoch: 7/7 -  - Step: 1653/3696 Training Loss: 0.746 -
# Epoch: 7/7 -  - Step: 1719/3696 Training Loss: 1.012 -
# Epoch: 7/7 -  - Step: 1785/3696 Training Loss: 0.532 -
# Epoch: 7/7 - Training Loss: 0.6696289553642273 - Validation Loss: 3.482829249003148 - Train Accuracy:  0.7553333044052124 - Validation Accuracy:  0.5415225028991699
# Epoch: 7/7 -  - Step: 1907/3696 Training Loss: 1.360 -
# Epoch: 7/7 -  - Step: 1968/3696 Training Loss: 0.630 -
# Epoch: 7/7 -  - Step: 2031/3696 Training Loss: 0.797 -
# Epoch: 7/7 -  - Step: 2094/3696 Training Loss: 0.486 -
# Epoch: 7/7 -  - Step: 2163/3696 Training Loss: 0.471 -
# Epoch: 7/7 -  - Step: 2224/3696 Training Loss: 0.421 -
# Epoch: 7/7 -  - Step: 2291/3696 Training Loss: 0.899 -
# Epoch: 7/7 -  - Step: 2357/3696 Training Loss: 0.670 -
# Epoch: 7/7 -  - Step: 2417/3696 Training Loss: 0.659 -
# Epoch: 7/7 -  - Step: 2477/3696 Training Loss: 0.679 -
# Epoch: 7/7 -  - Step: 2541/3696 Training Loss: 0.470 -
# Epoch: 7/7 -  - Step: 2605/3696 Training Loss: 0.488 -
# Epoch: 7/7 -  - Step: 2668/3696 Training Loss: 0.913 -
# Epoch: 7/7 -  - Step: 2729/3696 Training Loss: 0.521 -
# Epoch: 7/7 -  - Step: 2794/3696 Training Loss: 0.579 -
# Epoch: 7/7 -  - Step: 2855/3696 Training Loss: 0.428 -
# Epoch: 7/7 -  - Step: 2914/3696 Training Loss: 0.708 -
# Epoch: 7/7 -  - Step: 2973/3696 Training Loss: 0.718 -
# Epoch: 7/7 -  - Step: 3034/3696 Training Loss: 0.713 -
# Epoch: 7/7 -  - Step: 3096/3696 Training Loss: 0.742 -
# Epoch: 7/7 -  - Step: 3156/3696 Training Loss: 0.957 -
# Epoch: 7/7 -  - Step: 3221/3696 Training Loss: 0.624 -
# Epoch: 7/7 -  - Step: 3285/3696 Training Loss: 0.697 -
# Epoch: 7/7 -  - Step: 3350/3696 Training Loss: 0.584 -
# Epoch: 7/7 -  - Step: 3415/3696 Training Loss: 0.797 -
# Epoch: 7/7 -  - Step: 3472/3696 Training Loss: 0.498 -
# Epoch: 7/7 -  - Step: 3535/3696 Training Loss: 0.831 -
# Epoch: 7/7 -  - Step: 3597/3696 Training Loss: 0.462 -
# Epoch: 7/7 -  - Step: 3655/3696 Training Loss: 0.509 -
# Finished training

# %%
import pickle
train_loss_ls = history[0] + history2[0] + history3[0]  
val_loss_ls = history[1] + history2[1] + history3[1]  
val_acc_ls = history[2] + history2[2] + history3[2]  
train_acc_ls = history[3] + history2[3] + history3[3]  

time = str(datetime.now())

with open(current_model_path+time+"train_loss.pkl", "wb") as f:
    pickle.dump(train_loss_ls, f)
    
with open(current_model_path+time+"val_loss_ls.pkl", "wb") as f:
    pickle.dump(val_loss_ls, f)
    
with open(current_model_path+time+"val_acc_ls.pkl", "wb") as f:
    pickle.dump(val_acc_ls, f)
    
with open(current_model_path+time+"train_acc_ls.pkl", "wb") as f:
    pickle.dump(train_acc_ls, f)

# %%
fig, axs = plt.subplots(2,figsize=(10,15))

axs[0].plot(train_loss_ls, label = "train_loss")
axs[0].plot(val_loss_ls, label = "val_loss")
axs[0].legend()

axs[1].plot(train_acc_ls,label = "train_acc")
axs[1].plot(val_acc_ls,label = "val_acc")
axs[1].legend()

fig.savefig(current_model_path+'history.png')
